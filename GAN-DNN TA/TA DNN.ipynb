# %% [markdown]
# # IMPORT DATA

# %% [markdown]
# Superclasses enumerated by dataset description are as follows:
# ```
# Records | Superclass | Description
# 9528 | NORM | Normal ECG
# 5486 | MI | Myocardial Infarction
# 5250 | STTC | ST/T Change
# 4907 | CD | Conduction Disturbance
# 2655 | HYP | Hypertrophy
# ```

# %%
import os
import ast
import wfdb

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow.keras as keras

sns.set_style('darkgrid')

# %% [markdown]
# ## DATA LOADING

# %%
PATH_TO_DATA = 'D:\SMTR 7\Koding\Skripsi\ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3'

# Load data
ECG_df = pd.read_csv(os.path.join(PATH_TO_DATA, 'ptbxl_database.csv'), index_col='ecg_id')
ECG_df.scp_codes = ECG_df.scp_codes.apply(lambda x: ast.literal_eval(x))
ECG_df.patient_id = ECG_df.patient_id.astype(int)
ECG_df.nurse = ECG_df.nurse.astype('Int64')
ECG_df.site = ECG_df.site.astype('Int64')
ECG_df.validated_by = ECG_df.validated_by.astype('Int64')

# Load SCP statements
SCP_df = pd.read_csv(os.path.join(PATH_TO_DATA, 'scp_statements.csv'), index_col=0)
SCP_df = SCP_df[SCP_df.diagnostic == 1]

ECG_df
# Out:
#         patient_id    age  sex  height  weight  nurse  site      device  \
# ecg_id
# 1            15709   56.0    1     NaN    63.0      2     0   CS-12   E
# 2            13243   19.0    0     NaN    70.0      2     0   CS-12   E
# 3            20372   37.0    1     NaN    69.0      2     0   CS-12   E
# 4            17014   24.0    0     NaN    82.0      2     0   CS-12   E
# 5            17448   19.0    1     NaN    70.0      2     0   CS-12   E
# ...            ...    ...  ...     ...     ...    ...   ...         ...
# 21833        17180   67.0    1     NaN     NaN      1     2  AT-60    3
# 21834        20703  300.0    0     NaN     NaN      1     2  AT-60    3
# 21835        19311   59.0    1     NaN     NaN      1     2  AT-60    3
# 21836         8873   64.0    1     NaN     NaN      1     2  AT-60    3
# 21837        11744   68.0    0     NaN     NaN      1     2  AT-60    3
#
#              recording_date  \
# ecg_id
# 1       1984-11-09 09:17:34
# 2       1984-11-14 12:55:37
# 3       1984-11-15 12:49:10
# 4       1984-11-15 13:44:57
# 5       1984-11-17 10:43:15
# ...                     ...
# 21833   2001-05-31 09:14:35
# 21834   2001-06-05 11:33:39
# 21835   2001-06-08 10:30:27
# 21836   2001-06-09 18:21:49
# 21837   2001-06-11 16:43:01
#
#                                                    report  ...  \
# ecg_id                                                     ...
# 1                  sinusrhythmus periphere niederspannung  ...
# 2                     sinusbradykardie sonst normales ekg  ...
# 3                              sinusrhythmus normales ekg  ...
# 4                              sinusrhythmus normales ekg  ...
# 5                              sinusrhythmus normales ekg  ...
# ...                                                   ...  ...
# 21833   ventrikulÄre extrasystole(n) sinustachykardie ...  ...
# 21834   sinusrhythmus lagetyp normal qrs(t) abnorm    ...  ...
# 21835   sinusrhythmus lagetyp normal t abnorm in anter...  ...
# 21836   supraventrikulÄre extrasystole(n) sinusrhythmu...  ...
# 21837   sinusrhythmus p-sinistrocardiale lagetyp norma...  ...
#
#        validated_by_human  baseline_drift static_noise burst_noise  \
# ecg_id
# 1                    True             NaN    , I-V1,           NaN
# 2                    True             NaN          NaN         NaN
# 3                    True             NaN          NaN         NaN
# 4                    True    , II,III,AVF          NaN         NaN
# 5                    True   , III,AVR,AVF          NaN         NaN
# ...                   ...             ...          ...         ...
# 21833                True             NaN   , alles,           NaN
# 21834                True             NaN          NaN         NaN
# 21835                True             NaN   , I-AVR,           NaN
# 21836                True             NaN          NaN         NaN
# 21837                True             NaN   , I-AVL,           NaN
#
#         electrodes_problems  extra_beats  pacemaker  strat_fold  \
# ecg_id
# 1                       NaN          NaN        NaN           3
# 2                       NaN          NaN        NaN           2
# 3                       NaN          NaN        NaN           5
# 4                       NaN          NaN        NaN           3
# 5                       NaN          NaN        NaN           4
# ...                     ...          ...        ...         ...
# 21833                   NaN          1ES        NaN           7
# 21834                   NaN          NaN        NaN           4
# 21835                   NaN          NaN        NaN           2
# 21836                   NaN         SVES        NaN           8
# 21837                   NaN          NaN        NaN           9
#
#                       filename_lr                filename_hr
# ecg_id
# 1       records100/00000/00001_lr  records500/00000/00001_hr
# 2       records100/00000/00002_lr  records500/00000/00002_hr
# 3       records100/00000/00003_lr  records500/00000/00003_hr
# 4       records100/00000/00004_lr  records500/00000/00004_hr
# 5       records100/00000/00005_lr  records500/00000/00005_hr
# ...                           ...                        ...
# 21833   records100/21000/21833_lr  records500/21000/21833_hr
# 21834   records100/21000/21834_lr  records500/21000/21834_hr
# 21835   records100/21000/21835_lr  records500/21000/21835_hr
# 21836   records100/21000/21836_lr  records500/21000/21836_hr
# 21837   records100/21000/21837_lr  records500/21000/21837_hr
#
# [21799 rows x 27 columns]

# %%
# Get diagnostics subclass
def diagnostic_subclass(scp):
    res = set()
    for k in scp.keys():
        if k in SCP_df.index:
            res.add(SCP_df.loc[k].diagnostic_subclass)
    return list(res)
                    
ECG_df['scp_subclasses'] = ECG_df.scp_codes.apply(diagnostic_subclass)

# %% [markdown]
# ## Filtering

# %%
# Membuat list subclass yang diinginkan
selected_subclasses = ['NORM', 'PMI', 'LMI', 'AMI', 'IMI']

# Melakukan filtering
filtered_ECG_df = ECG_df[ECG_df['scp_subclasses'].apply(lambda x: any(subclass in x for subclass in selected_subclasses))]

# %%
filtered_ECG_df.shape
# Out:
# (14982, 28)

# %%
# Menghitung jumlah data untuk setiap subclass
subclass_counts = {}
for subclass in selected_subclasses:
    count = len(filtered_ECG_df[filtered_ECG_df['scp_subclasses'].apply(lambda x: subclass in x)])
    subclass_counts[subclass] = count

# Membuat pie chart
plt.figure(figsize=(10, 8))
plt.pie(subclass_counts.values(), 
        labels=subclass_counts.keys(),
        autopct='%1.1f%%',
        startangle=90)
plt.title('Distribusi Data ECG berdasarkan Subclass')

# Menambahkan legend
plt.legend(title="Subclass", 
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.axis('equal')
plt.show()

# Menampilkan jumlah data dalam bentuk tabel
print("\nJumlah data untuk setiap subclass:")
for subclass, count in subclass_counts.items():
    print(f"{subclass}: {count} data")

print(f"\nTotal keseluruhan data: {sum(subclass_counts.values())} data")
# Out:
# Jumlah data untuk setiap subclass:
# NORM: 9514 data
# PMI: 17 data
# LMI: 201 data
# AMI: 3078 data
# IMI: 3271 data
#
# Total keseluruhan data: 16081 data

# %% [markdown]
# ## Load RawData

# %%
def load_raw_data(df, sampling_rate, path):
    if sampling_rate == 100:
        data = [wfdb.rdsamp(os.path.join(path, f)) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(os.path.join(path, f)) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

sampling_rate = 100

ECG_data = load_raw_data(filtered_ECG_df, sampling_rate, PATH_TO_DATA)

ECG_data.shape
# Out:
# (14982, 1000, 12)

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# ## Fake Data using GAN

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Memisahkan data PMI dan LMI
pmi_data = ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'PMI' in x)]
lmi_data = ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'LMI' in x)]

# Fungsi untuk membagi data
def split_data(data, test_size=0.2):
    n_samples = len(data)
    n_test = int(n_samples * test_size)
    
    indices = np.random.permutation(n_samples)
    test_idx = indices[:n_test]
    train_idx = indices[n_test:]
    
    return data[train_idx], data[test_idx]

# Membagi data menjadi train dan test
pmi_train, pmi_test = split_data(pmi_data)
lmi_train, lmi_test = split_data(lmi_data)

# Preprocessing
def preprocess_data(data):
    data = (data - np.mean(data)) / np.std(data)
    return data.reshape(-1, data.shape[1], 1)

# Preprocess data train dan test
pmi_train_processed = preprocess_data(pmi_train)
pmi_test_processed = preprocess_data(pmi_test)
lmi_train_processed = preprocess_data(lmi_train)
lmi_test_processed = preprocess_data(lmi_test)

# Print info shape data
print("Shape PMI train:", pmi_train_processed.shape)
print("Shape LMI train:", lmi_train_processed.shape)

# Generator model
def build_generator():
    model = keras.Sequential([
        keras.layers.Dense(250 * 4, input_shape=(100,)),
        keras.layers.Reshape((250, 4)),
        
        keras.layers.Conv1D(128, kernel_size=3, padding='same'),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(alpha=0.2),
        
        keras.layers.UpSampling1D(2),
        keras.layers.Conv1D(64, kernel_size=3, padding='same'),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(alpha=0.2),
        
        keras.layers.UpSampling1D(2),
        keras.layers.Conv1D(32, kernel_size=3, padding='same'),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(alpha=0.2),
        
        keras.layers.Conv1D(1, kernel_size=3, padding='same', activation='tanh')
    ])
    return model

# Discriminator model
def build_discriminator():
    model = keras.Sequential([
        keras.layers.Conv1D(64, kernel_size=3, strides=2, padding='same', 
                           input_shape=(1000, 1)),
        keras.layers.LeakyReLU(alpha=0.2),
        keras.layers.Dropout(0.3),
        
        keras.layers.Conv1D(128, kernel_size=3, strides=2, padding='same'),
        keras.layers.LeakyReLU(alpha=0.2),
        keras.layers.Dropout(0.3),
        
        keras.layers.Flatten(),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

# Fungsi training
def train_gan(generator, discriminator, train_data, target_samples=3000, epochs=500, batch_size=16):
    # Optimizers
    generator_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
    
    # Loss function
    cross_entropy = tf.keras.losses.BinaryCrossentropy()
    
    @tf.function
    def train_step(real_signals):
        batch_size = tf.shape(real_signals)[0]
        noise = tf.random.normal([batch_size, 100])
        
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            generated_signals = generator(noise, training=True)
            
            real_output = discriminator(real_signals, training=True)
            fake_output = discriminator(generated_signals, training=True)
            
            gen_loss = cross_entropy(tf.ones_like(fake_output), fake_output)
            real_loss = cross_entropy(tf.ones_like(real_output), real_output)
            fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
            disc_loss = real_loss + fake_loss
            
        gen_gradients = gen_tape.gradient(gen_loss, generator.trainable_variables)
        disc_gradients = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
        
        generator_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))
        discriminator_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
        
        return gen_loss, disc_loss

    generated_samples = []
    
    # Training loop
    for epoch in range(epochs):
        idx = np.random.randint(0, train_data.shape[0], batch_size)
        real_batch = train_data[idx]
        
        g_loss, d_loss = train_step(real_batch)
        
        if epoch % 10 == 0:
            print(f"Epoch {epoch}, G Loss: {g_loss:.4f}, D Loss: {d_loss:.4f}")
    
    # Generate samples until we reach target number
    remaining_samples = target_samples
    batch_size = 32  # Larger batch size for generation
    
    while remaining_samples > 0:
        current_batch = min(batch_size, remaining_samples)
        noise = tf.random.normal([current_batch, 100])
        generated = generator(noise, training=False)
        generated_samples.append(generated.numpy())
        remaining_samples -= current_batch
        
        # Print progress
        print(f"Generated {len(generated_samples) * batch_size} samples out of {target_samples}")
    
    return np.concatenate(generated_samples)[:target_samples]

# Fungsi visualisasi
def plot_comparison(real_data, fake_data, title):
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(real_data[0].reshape(-1))
    plt.title(f'Data Asli {title}')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    
    plt.subplot(1, 2, 2)
    plt.plot(fake_data[0].reshape(-1))
    plt.title(f'Data Palsu {title}')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    
    plt.tight_layout()
    plt.show()

# Build models
generator = build_generator()
discriminator = build_discriminator()

# Training PMI
print("Training GAN untuk PMI data:")
pmi_fake = train_gan(generator, discriminator, pmi_train_processed, target_samples=3000)

# Training LMI
print("\nTraining GAN untuk LMI data:")
lmi_fake = train_gan(generator, discriminator, lmi_train_processed, target_samples=3000)

# Visualisasi hasil
plot_comparison(pmi_train_processed, pmi_fake, "PMI")
plot_comparison(lmi_train_processed, lmi_fake, "LMI")

# Informasi jumlah data
print("\nInformasi jumlah data:")
print(f"PMI asli - Training: {len(pmi_train_processed)}, Testing: {len(pmi_test_processed)}")
print(f"PMI palsu: {len(pmi_fake)}")
print(f"LMI asli - Training: {len(lmi_train_processed)}, Testing: {len(lmi_test_processed)}")
print(f"LMI palsu: {len(lmi_fake)}")

# Save generated data (optional)
np.save('pmi_fake_data.npy', pmi_fake)
np.save('lmi_fake_data.npy', lmi_fake)
# Out:
# Shape PMI train: (168, 1000, 1)
# Shape LMI train: (1932, 1000, 1)
# Training GAN untuk PMI data:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 0, G Loss: 0.6673, D Loss: 1.3591
# Epoch 10, G Loss: 0.7449, D Loss: 1.3731
# Epoch 20, G Loss: 0.7407, D Loss: 1.3547
# Epoch 30, G Loss: 0.7224, D Loss: 1.3058
# Epoch 40, G Loss: 0.6676, D Loss: 1.3948
# Epoch 50, G Loss: 0.6953, D Loss: 1.3522
# Epoch 60, G Loss: 0.6910, D Loss: 1.3263
# Epoch 70, G Loss: 0.7933, D Loss: 1.2985
# Epoch 80, G Loss: 0.7059, D Loss: 1.2735
# Epoch 90, G Loss: 0.8495, D Loss: 1.1116
# Epoch 100, G Loss: 0.6861, D Loss: 1.5108
# Epoch 110, G Loss: 0.9541, D Loss: 1.0171
# Epoch 120, G Loss: 0.6946, D Loss: 1.3401
# Epoch 130, G Loss: 0.7324, D Loss: 1.3504
# Epoch 140, G Loss: 0.8100, D Loss: 1.0869
# Epoch 150, G Loss: 0.6395, D Loss: 1.4694
# Epoch 160, G Loss: 0.7971, D Loss: 1.1795
# Epoch 170, G Loss: 0.7484, D Loss: 1.1400
# Epoch 180, G Loss: 0.6364, D Loss: 1.2672
# Epoch 190, G Loss: 0.8850, D Loss: 1.0892
# Epoch 200, G Loss: 0.8925, D Loss: 1.1215
# Epoch 210, G Loss: 0.7260, D Loss: 1.3360
# Epoch 220, G Loss: 0.9200, D Loss: 0.9851
# Epoch 230, G Loss: 0.8303, D Loss: 1.1495
# Epoch 240, G Loss: 0.8126, D Loss: 1.2682
# Epoch 250, G Loss: 1.0060, D Loss: 0.9778
# Epoch 260, G Loss: 1.0804, D Loss: 0.8550
# Epoch 270, G Loss: 0.7197, D Loss: 1.2114
# Epoch 280, G Loss: 0.9715, D Loss: 0.8912
# Epoch 290, G Loss: 0.8466, D Loss: 1.0995
# Epoch 300, G Loss: 0.9015, D Loss: 1.0539
# Epoch 310, G Loss: 1.1370, D Loss: 0.8587
# Epoch 320, G Loss: 1.1467, D Loss: 0.7999
# Epoch 330, G Loss: 0.9568, D Loss: 0.9527
# Epoch 340, G Loss: 1.0971, D Loss: 0.7707
# Epoch 350, G Loss: 1.1499, D Loss: 0.7164
# Epoch 360, G Loss: 1.1704, D Loss: 0.7415
# Epoch 370, G Loss: 1.3402, D Loss: 0.6877
# Epoch 380, G Loss: 1.3205, D Loss: 0.6848
# Epoch 390, G Loss: 1.2576, D Loss: 0.6527
# Epoch 400, G Loss: 1.4228, D Loss: 0.7024
# Epoch 410, G Loss: 1.3837, D Loss: 0.5820
# Epoch 420, G Loss: 1.4856, D Loss: 0.5630
# Epoch 430, G Loss: 1.5670, D Loss: 0.5030
# Epoch 440, G Loss: 1.6376, D Loss: 0.4866
# Epoch 450, G Loss: 1.5565, D Loss: 0.5205
# Epoch 460, G Loss: 1.5380, D Loss: 0.4067
# Epoch 470, G Loss: 1.5837, D Loss: 0.4142
# Epoch 480, G Loss: 1.7696, D Loss: 0.4373
# Epoch 490, G Loss: 1.9055, D Loss: 0.3931
# Generated 32 samples out of 3000
# Generated 64 samples out of 3000
# Generated 96 samples out of 3000
# Generated 128 samples out of 3000
# Generated 160 samples out of 3000
# Generated 192 samples out of 3000
# Generated 224 samples out of 3000
# Generated 256 samples out of 3000
# Generated 288 samples out of 3000
# Generated 320 samples out of 3000
# Generated 352 samples out of 3000
# Generated 384 samples out of 3000
# Generated 416 samples out of 3000
# Generated 448 samples out of 3000
# Generated 480 samples out of 3000
# Generated 512 samples out of 3000
# Generated 544 samples out of 3000
# Generated 576 samples out of 3000
# Generated 608 samples out of 3000
# Generated 640 samples out of 3000
# Generated 672 samples out of 3000
# Generated 704 samples out of 3000
# Generated 736 samples out of 3000
# Generated 768 samples out of 3000
# Generated 800 samples out of 3000
# Generated 832 samples out of 3000
# Generated 864 samples out of 3000
# Generated 896 samples out of 3000
# Generated 928 samples out of 3000
# Generated 960 samples out of 3000
# Generated 992 samples out of 3000
# Generated 1024 samples out of 3000
# Generated 1056 samples out of 3000
# Generated 1088 samples out of 3000
# Generated 1120 samples out of 3000
# Generated 1152 samples out of 3000
# Generated 1184 samples out of 3000
# Generated 1216 samples out of 3000
# Generated 1248 samples out of 3000
# Generated 1280 samples out of 3000
# Generated 1312 samples out of 3000
# Generated 1344 samples out of 3000
# Generated 1376 samples out of 3000
# Generated 1408 samples out of 3000
# Generated 1440 samples out of 3000
# Generated 1472 samples out of 3000
# Generated 1504 samples out of 3000
# Generated 1536 samples out of 3000
# Generated 1568 samples out of 3000
# Generated 1600 samples out of 3000
# Generated 1632 samples out of 3000
# Generated 1664 samples out of 3000
# Generated 1696 samples out of 3000
# Generated 1728 samples out of 3000
# Generated 1760 samples out of 3000
# Generated 1792 samples out of 3000
# Generated 1824 samples out of 3000
# Generated 1856 samples out of 3000
# Generated 1888 samples out of 3000
# Generated 1920 samples out of 3000
# Generated 1952 samples out of 3000
# Generated 1984 samples out of 3000
# Generated 2016 samples out of 3000
# Generated 2048 samples out of 3000
# Generated 2080 samples out of 3000
# Generated 2112 samples out of 3000
# Generated 2144 samples out of 3000
# Generated 2176 samples out of 3000
# Generated 2208 samples out of 3000
# Generated 2240 samples out of 3000
# Generated 2272 samples out of 3000
# Generated 2304 samples out of 3000
# Generated 2336 samples out of 3000
# Generated 2368 samples out of 3000
# Generated 2400 samples out of 3000
# Generated 2432 samples out of 3000
# Generated 2464 samples out of 3000
# Generated 2496 samples out of 3000
# Generated 2528 samples out of 3000
# Generated 2560 samples out of 3000
# Generated 2592 samples out of 3000
# Generated 2624 samples out of 3000
# Generated 2656 samples out of 3000
# Generated 2688 samples out of 3000
# Generated 2720 samples out of 3000
# Generated 2752 samples out of 3000
# Generated 2784 samples out of 3000
# Generated 2816 samples out of 3000
# Generated 2848 samples out of 3000
# Generated 2880 samples out of 3000
# Generated 2912 samples out of 3000
# Generated 2944 samples out of 3000
# Generated 2976 samples out of 3000
# Generated 3008 samples out of 3000
#
# Training GAN untuk LMI data:
# Epoch 0, G Loss: 1.6989, D Loss: 0.5977
# Epoch 10, G Loss: 1.3953, D Loss: 0.6228
# Epoch 20, G Loss: 1.4326, D Loss: 0.6566
# Epoch 30, G Loss: 1.2457, D Loss: 0.7779
# Epoch 40, G Loss: 1.3726, D Loss: 0.6723
# Epoch 50, G Loss: 1.4636, D Loss: 0.5344
# Epoch 60, G Loss: 1.4803, D Loss: 0.6109
# Epoch 70, G Loss: 1.8760, D Loss: 0.5108
# Epoch 80, G Loss: 1.3837, D Loss: 0.4391
# Epoch 90, G Loss: 1.7632, D Loss: 0.4792
# Epoch 100, G Loss: 1.8341, D Loss: 0.4206
# Epoch 110, G Loss: 1.9725, D Loss: 0.3266
# Epoch 120, G Loss: 1.7629, D Loss: 0.4177
# Epoch 130, G Loss: 1.9020, D Loss: 0.2861
# Epoch 140, G Loss: 2.1677, D Loss: 0.4956
# Epoch 150, G Loss: 1.8648, D Loss: 0.3155
# Epoch 160, G Loss: 1.8284, D Loss: 0.4688
# Epoch 170, G Loss: 1.6000, D Loss: 0.4300
# Epoch 180, G Loss: 1.8328, D Loss: 0.4076
# Epoch 190, G Loss: 2.1449, D Loss: 0.2543
# Epoch 200, G Loss: 2.1255, D Loss: 0.2289
# Epoch 210, G Loss: 2.2080, D Loss: 0.4216
# Epoch 220, G Loss: 1.7242, D Loss: 0.3078
# Epoch 230, G Loss: 2.1696, D Loss: 0.2593
# Epoch 240, G Loss: 2.0116, D Loss: 0.1618
# Epoch 250, G Loss: 2.0537, D Loss: 0.2668
# Epoch 260, G Loss: 2.4102, D Loss: 0.3589
# Epoch 270, G Loss: 2.2314, D Loss: 0.3134
# Epoch 280, G Loss: 2.3059, D Loss: 0.4591
# Epoch 290, G Loss: 2.3178, D Loss: 0.2728
# Epoch 300, G Loss: 1.8712, D Loss: 0.4012
# Epoch 310, G Loss: 2.2683, D Loss: 0.6017
# Epoch 320, G Loss: 2.2735, D Loss: 0.1753
# Epoch 330, G Loss: 2.0539, D Loss: 0.2530
# Epoch 340, G Loss: 2.4075, D Loss: 0.1331
# Epoch 350, G Loss: 2.4516, D Loss: 0.3047
# Epoch 360, G Loss: 2.0910, D Loss: 0.1417
# Epoch 370, G Loss: 2.2060, D Loss: 0.3471
# Epoch 380, G Loss: 2.5113, D Loss: 0.3250
# Epoch 390, G Loss: 1.9797, D Loss: 0.3054
# Epoch 400, G Loss: 1.5618, D Loss: 0.3792
# Epoch 410, G Loss: 1.9897, D Loss: 0.1998
# Epoch 420, G Loss: 2.6778, D Loss: 0.2077
# Epoch 430, G Loss: 2.4312, D Loss: 0.1398
# Epoch 440, G Loss: 2.6048, D Loss: 0.2702
# Epoch 450, G Loss: 2.4851, D Loss: 0.1089
# Epoch 460, G Loss: 2.0609, D Loss: 0.3017
# Epoch 470, G Loss: 2.3751, D Loss: 0.2974
# Epoch 480, G Loss: 2.4081, D Loss: 0.2979
# Epoch 490, G Loss: 2.5090, D Loss: 0.1710
# Generated 32 samples out of 3000
# Generated 64 samples out of 3000
# Generated 96 samples out of 3000
# Generated 128 samples out of 3000
# Generated 160 samples out of 3000
# Generated 192 samples out of 3000
# Generated 224 samples out of 3000
# Generated 256 samples out of 3000
# Generated 288 samples out of 3000
# Generated 320 samples out of 3000
# Generated 352 samples out of 3000
# Generated 384 samples out of 3000
# Generated 416 samples out of 3000
# Generated 448 samples out of 3000
# Generated 480 samples out of 3000
# Generated 512 samples out of 3000
# Generated 544 samples out of 3000
# Generated 576 samples out of 3000
# Generated 608 samples out of 3000
# Generated 640 samples out of 3000
# Generated 672 samples out of 3000
# Generated 704 samples out of 3000
# Generated 736 samples out of 3000
# Generated 768 samples out of 3000
# Generated 800 samples out of 3000
# Generated 832 samples out of 3000
# Generated 864 samples out of 3000
# Generated 896 samples out of 3000
# Generated 928 samples out of 3000
# Generated 960 samples out of 3000
# Generated 992 samples out of 3000
# Generated 1024 samples out of 3000
# Generated 1056 samples out of 3000
# Generated 1088 samples out of 3000
# Generated 1120 samples out of 3000
# Generated 1152 samples out of 3000
# Generated 1184 samples out of 3000
# Generated 1216 samples out of 3000
# Generated 1248 samples out of 3000
# Generated 1280 samples out of 3000
# Generated 1312 samples out of 3000
# Generated 1344 samples out of 3000
# Generated 1376 samples out of 3000
# Generated 1408 samples out of 3000
# Generated 1440 samples out of 3000
# Generated 1472 samples out of 3000
# Generated 1504 samples out of 3000
# Generated 1536 samples out of 3000
# Generated 1568 samples out of 3000
# Generated 1600 samples out of 3000
# Generated 1632 samples out of 3000
# Generated 1664 samples out of 3000
# Generated 1696 samples out of 3000
# Generated 1728 samples out of 3000
# Generated 1760 samples out of 3000
# Generated 1792 samples out of 3000
# Generated 1824 samples out of 3000
# Generated 1856 samples out of 3000
# Generated 1888 samples out of 3000
# Generated 1920 samples out of 3000
# Generated 1952 samples out of 3000
# Generated 1984 samples out of 3000
# Generated 2016 samples out of 3000
# Generated 2048 samples out of 3000
# Generated 2080 samples out of 3000
# Generated 2112 samples out of 3000
# Generated 2144 samples out of 3000
# Generated 2176 samples out of 3000
# Generated 2208 samples out of 3000
# Generated 2240 samples out of 3000
# Generated 2272 samples out of 3000
# Generated 2304 samples out of 3000
# Generated 2336 samples out of 3000
# Generated 2368 samples out of 3000
# Generated 2400 samples out of 3000
# Generated 2432 samples out of 3000
# Generated 2464 samples out of 3000
# Generated 2496 samples out of 3000
# Generated 2528 samples out of 3000
# Generated 2560 samples out of 3000
# Generated 2592 samples out of 3000
# Generated 2624 samples out of 3000
# Generated 2656 samples out of 3000
# Generated 2688 samples out of 3000
# Generated 2720 samples out of 3000
# Generated 2752 samples out of 3000
# Generated 2784 samples out of 3000
# Generated 2816 samples out of 3000
# Generated 2848 samples out of 3000
# Generated 2880 samples out of 3000
# Generated 2912 samples out of 3000
# Generated 2944 samples out of 3000
# Generated 2976 samples out of 3000
# Generated 3008 samples out of 3000
# Informasi jumlah data:
# PMI asli - Training: 168, Testing: 36
# PMI palsu: 3000
# LMI asli - Training: 1932, Testing: 480
# LMI palsu: 3000

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Function to prepare labels for the data
def prepare_labels(data_dict):
    labels = []
    combined_data = []
    
    for label, data in data_dict.items():
        n_samples = len(data)
        labels.extend([label] * n_samples)
        combined_data.append(data)
    
    return np.concatenate(combined_data), np.array(labels)

# Let's first check the shapes of our data
print("Original shapes:")
print("LMI fake shape:", lmi_fake.shape)
print("PMI fake shape:", pmi_fake.shape)
print("Real ECG data shape:", ECG_data.shape)

# Reshape GAN-generated data to match real data dimensions
# We'll duplicate the single channel 12 times
def reshape_gan_data(gan_data):
    # First reshape back to (n_samples, timesteps)
    n_samples = gan_data.shape[0]
    timesteps = 1000  # Based on your original data
    reshaped = gan_data.reshape(n_samples, timesteps)
    
    # Create 12 copies of the channel
    multi_channel = np.stack([reshaped] * 12, axis=-1)
    return multi_channel

# Reshape GAN data
lmi_fake_reshaped = reshape_gan_data(lmi_fake)
pmi_fake_reshaped = reshape_gan_data(pmi_fake)

print("\nAfter reshaping:")
print("LMI fake reshaped shape:", lmi_fake_reshaped.shape)
print("PMI fake reshaped shape:", pmi_fake_reshaped.shape)

# Prepare real data dictionary
real_data = {
    'NORM': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'NORM' in x)],
    'AMI': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'AMI' in x)],
    'IMI': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'IMI' in x)],
    'LMI': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'LMI' in x)],
    'PMI': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'PMI' in x)]
}

# Add GAN-generated data
real_data['LMI'] = np.concatenate([real_data['LMI'], lmi_fake_reshaped])
real_data['PMI'] = np.concatenate([real_data['PMI'], pmi_fake_reshaped])

# Prepare the combined dataset
X, y = prepare_labels(real_data)

# Preprocess the data
# Normalize each channel independently
X_processed = np.zeros_like(X, dtype=np.float32)
for i in range(12):
    X_processed[:, :, i] = (X[:, :, i] - np.mean(X[:, :, i])) / np.std(X[:, :, i])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# Print information about the dataset
print("\nDataset Information:")
print("===================")
print(f"Total number of samples: {len(X)}")
print("Input shape:", X.shape)

print("\nClass distribution in complete dataset:")
for label in np.unique(y):
    count = np.sum(y == label)
    percentage = (count / len(y)) * 100
    print(f"{label}: {count} samples ({percentage:.2f}%)")

print("\nTraining set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)

print("\nClass distribution in training set:")
for label in np.unique(y_train):
    count = np.sum(y_train == label)
    percentage = (count / len(y_train)) * 100
    print(f"{label}: {count} samples ({percentage:.2f}%)")

print("\nClass distribution in testing set:")
for label in np.unique(y_test):
    count = np.sum(y_test == label)
    percentage = (count / len(y_test)) * 100
    print(f"{label}: {count} samples ({percentage:.2f}%)")

# Save the processed datasets (optional)
np.save('X_train.npy', X_train)
np.save('X_test.npy', X_test)
np.save('y_train.npy', y_train)
np.save('y_test.npy', y_test)
# Out:
# Original shapes:
# LMI fake shape: (3000, 1000, 1)
# PMI fake shape: (3000, 1000, 1)
# Real ECG data shape: (14982, 1000, 12)
#
# After reshaping:
# LMI fake reshaped shape: (3000, 1000, 12)
# PMI fake reshaped shape: (3000, 1000, 12)
#
# Dataset Information:
# ===================
# Total number of samples: 22081
# Input shape: (22081, 1000, 12)
#
# Class distribution in complete dataset:
# AMI: 3078 samples (13.94%)
# IMI: 3271 samples (14.81%)
# LMI: 3201 samples (14.50%)
# NORM: 9514 samples (43.09%)
# PMI: 3017 samples (13.66%)
#
# Training set shape: (17664, 1000, 12)
# Testing set shape: (4417, 1000, 12)
#
# Class distribution in training set:
# AMI: 2462 samples (13.94%)
# IMI: 2617 samples (14.82%)
# LMI: 2561 samples (14.50%)
# NORM: 7611 samples (43.09%)
# PMI: 2413 samples (13.66%)
#
# Class distribution in testing set:
# AMI: 616 samples (13.95%)
# IMI: 654 samples (14.81%)
# LMI: 640 samples (14.49%)
# NORM: 1903 samples (43.08%)
# PMI: 604 samples (13.67%)

# %% [markdown]
# ## Hasil GAN

# %%
# Menghitung jumlah data untuk setiap subclass (data asli)
def count_original_data(filtered_df, subclasses):
    counts = {}
    for subclass in subclasses:
        count = len(filtered_df[filtered_df['scp_subclasses'].apply(lambda x: subclass in x)])
        counts[subclass] = count
    return counts

# Hitung jumlah data asli
original_counts = count_original_data(filtered_ECG_df, selected_subclasses)

# Hitung jumlah data setelah GAN
# Asumsikan kita memiliki data palsu untuk PMI dan LMI
gan_counts = original_counts.copy()
gan_counts['PMI'] += len(pmi_fake)  # Tambahkan jumlah data PMI palsu
gan_counts['LMI'] += len(lmi_fake)  # Tambahkan jumlah data LMI palsu

# Membuat subplot untuk membandingkan distribusi sebelum dan sesudah GAN
plt.figure(figsize=(20, 8))

# Pie chart untuk data asli
plt.subplot(1, 2, 1)
plt.pie(original_counts.values(), 
        labels=original_counts.keys(),
        autopct='%1.1f%%',
        startangle=90)
plt.title('Distribusi Data ECG Original')

# Pie chart untuk data setelah GAN
plt.subplot(1, 2, 2)
plt.pie(gan_counts.values(), 
        labels=gan_counts.keys(),
        autopct='%1.1f%%',
        startangle=90)
plt.title('Distribusi Data ECG Setelah GAN')

plt.tight_layout()
plt.show()

# Menampilkan jumlah data dalam bentuk tabel
print("\nJumlah data untuk setiap subclass:")
print("\nData Original:")
for subclass, count in original_counts.items():
    print(f"{subclass}: {count} data")

print("\nData Setelah GAN:")
for subclass, count in gan_counts.items():
    print(f"{subclass}: {count} data")

print("\nJumlah data yang ditambahkan oleh GAN:")
print(f"PMI: {len(pmi_fake)} data")
print(f"LMI: {len(lmi_fake)} data")

# Menghitung persentase peningkatan
pmi_increase = (gan_counts['PMI'] - original_counts['PMI']) / original_counts['PMI'] * 100
lmi_increase = (gan_counts['LMI'] - original_counts['LMI']) / original_counts['LMI'] * 100

print(f"\nPersentase peningkatan data:")
print(f"PMI: {pmi_increase:.1f}%")
print(f"LMI: {lmi_increase:.1f}%")
# Out:
# Jumlah data untuk setiap subclass:
#
# Data Original:
# NORM: 9514 data
# PMI: 17 data
# LMI: 201 data
# AMI: 3078 data
# IMI: 3271 data
#
# Data Setelah GAN:
# NORM: 9514 data
# PMI: 3017 data
# LMI: 3201 data
# AMI: 3078 data
# IMI: 3271 data
#
# Jumlah data yang ditambahkan oleh GAN:
# PMI: 3000 data
# LMI: 3000 data
#
# Persentase peningkatan data:
# PMI: 17647.1%
# LMI: 1492.5%

# %%
# Menggabungkan data asli dan data palsu untuk training
def combine_data_for_training(real_train, fake_data):
    # Menggabungkan data training asli dengan data palsu
    combined_train = np.concatenate([real_train, fake_data])
    return combined_train

# Fungsi untuk membuat dataset final
def prepare_final_dataset():
    # Data Training = Data training asli + Data GAN
    pmi_combined_train = combine_data_for_training(pmi_train_processed, pmi_fake)
    lmi_combined_train = combine_data_for_training(lmi_train_processed, lmi_fake)
    
    # Data Testing = Hanya data testing asli
    pmi_final_test = pmi_test_processed
    lmi_final_test = lmi_test_processed
    
    # Print informasi dataset
    print("\nInformasi Dataset Final:")
    print("\nPMI:")
    print(f"Training (asli + palsu): {len(pmi_combined_train)} sampel")
    print(f"- Data asli: {len(pmi_train_processed)} sampel")
    print(f"- Data palsu: {len(pmi_fake)} sampel")
    print(f"Testing (hanya asli): {len(pmi_final_test)} sampel")
    
    print("\nLMI:")
    print(f"Training (asli + palsu): {len(lmi_combined_train)} sampel")
    print(f"- Data asli: {len(lmi_train_processed)} sampel")
    print(f"- Data palsu: {len(lmi_fake)} sampel")
    print(f"Testing (hanya asli): {len(lmi_final_test)} sampel")
    
    return {
        'pmi_train': pmi_combined_train,
        'pmi_test': pmi_final_test,
        'lmi_train': lmi_combined_train,
        'lmi_test': lmi_final_test
    }

# Membuat dataset final
final_dataset = prepare_final_dataset()

# Optional: Simpan dataset
np.save('pmi_train_final.npy', final_dataset['pmi_train'])
np.save('pmi_test_final.npy', final_dataset['pmi_test'])
np.save('lmi_train_final.npy', final_dataset['lmi_train'])
np.save('lmi_test_final.npy', final_dataset['lmi_test'])

# Visualisasi distribusi data
def plot_data_distribution():
    labels = ['PMI', 'LMI']
    train_real = [len(pmi_train_processed), len(lmi_train_processed)]
    train_fake = [len(pmi_fake), len(lmi_fake)]
    test_data = [len(final_dataset['pmi_test']), len(final_dataset['lmi_test'])]
    
    x = np.arange(len(labels))
    width = 0.25
    
    fig, ax = plt.subplots(figsize=(10, 6))
    rects1 = ax.bar(x - width, train_real, width, label='Training (Asli)')
    rects2 = ax.bar(x, train_fake, width, label='Training (GAN)')
    rects3 = ax.bar(x + width, test_data, width, label='Testing (Asli)')
    
    ax.set_ylabel('Jumlah Sampel')
    ax.set_title('Distribusi Data')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()
    
    plt.tight_layout()
    plt.show()

# Tampilkan visualisasi
plot_data_distribution()
# Out:
# Informasi Dataset Final:
#
# PMI:
# Training (asli + palsu): 3168 sampel
# - Data asli: 168 sampel
# - Data palsu: 3000 sampel
# Testing (hanya asli): 36 sampel
#
# LMI:
# Training (asli + palsu): 4932 sampel
# - Data asli: 1932 sampel
# - Data palsu: 3000 sampel
# Testing (hanya asli): 480 sampel

# %%
print("Shape data:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Shape data:
# X_train shape: (17664, 1000, 12)
# y_train shape: (17664,)
# X_test shape: (4417, 1000, 12)
# y_test shape: (4417,)

# %% [markdown]
# # MODEL

# %% [markdown]
# ## RNN model

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import os

# Buat folder untuk menyimpan hasil setiap fold
if not os.path.exists('fold_results'):
    os.makedirs('fold_results')

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y_train)
y_train_cat = to_categorical(y_encoded)

y_test_encoded = le.transform(y_test)
y_test_cat = to_categorical(y_test_encoded)

def build_dnn_model(input_shape, num_classes=5):
    # Menghitung jumlah fitur total
    total_features = input_shape[0] * input_shape[1]
    
    model = Sequential([
        # Flatten layer untuk mengubah input 3D menjadi 1D
        tf.keras.layers.Flatten(input_shape=input_shape),
        
        # Hidden layers
        Dense(256, activation='relu'),
        Dropout(0.3),
        
        Dense(128, activation='relu'),
        Dropout(0.3),
        
        Dense(64, activation='relu'),
        Dropout(0.2),
        
        Dense(32, activation='relu'),
        Dropout(0.2),
        
        # Output layer
        Dense(num_classes, activation='softmax')
    ])
    
    optimizer = Adam(learning_rate=0.001)
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

def get_callbacks(fold):
    fold_dir = f'fold_results/fold_{fold}'
    if not os.path.exists(fold_dir):
        os.makedirs(fold_dir)
        
    return [
        ModelCheckpoint(
            f'{fold_dir}/best_dnn_model_5class.keras',
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1,
            mode='max'
        ),
        #EarlyStopping(
            #monitor='val_loss',
            #patience=10,
            #restore_best_weights=True,
            #verbose=1
        #),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=0.00001,
            verbose=1
        )
    ]

def plot_training_history(history, fold, save_dir):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    # Plot accuracy
    ax1.plot(history.history['accuracy'])
    ax1.plot(history.history['val_accuracy'])
    ax1.set_title(f'Model Accuracy - Fold {fold}')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['Train', 'Validation'])
    
    # Plot loss
    ax2.plot(history.history['loss'])
    ax2.plot(history.history['val_loss'])
    ax2.set_title(f'Model Loss - Fold {fold}')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend(['Train', 'Validation'])
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/training_history.png')
    plt.close()

def evaluate_model(model, X_test, y_test, class_names, fold, save_dir):
    # Prediksi
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)
    
    # Metrics
    accuracy = accuracy_score(y_test_classes, y_pred_classes)
    precision = precision_score(y_test_classes, y_pred_classes, average='weighted')
    recall = recall_score(y_test_classes, y_pred_classes, average='weighted')
    f1 = f1_score(y_test_classes, y_pred_classes, average='weighted')
    
    # Save metrics to file
    with open(f'{save_dir}/evaluation_metrics.txt', 'w', encoding='utf-8') as f:
        f.write(f"Fold {fold} Evaluation Metrics:\n")
        f.write(f"Accuracy: {accuracy:.4f}\n")
        f.write(f"Precision: {precision:.4f}\n")
        f.write(f"Recall: {recall:.4f}\n")
        f.write(f"F1-Score: {f1:.4f}\n")
    
    # Confusion Matrix
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title(f'Confusion Matrix - Fold {fold}')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.savefig(f'{save_dir}/confusion_matrix.png')
    plt.close()
    
    # Save confusion matrix as CSV
    cm_df = pd.DataFrame(cm, 
                        index=class_names,
                        columns=class_names)
    cm_df.to_csv(f'{save_dir}/confusion_matrix.csv')
    
    # Per-class metrics
    per_class_metrics = []
    for i, class_name in enumerate(class_names):
        class_precision = precision_score(y_test_classes, y_pred_classes, average=None)[i]
        class_recall = recall_score(y_test_classes, y_pred_classes, average=None)[i]
        class_f1 = f1_score(y_test_classes, y_pred_classes, average=None)[i]
        
        tp = cm[i, i]
        fp = np.sum(cm[:, i]) - tp
        fn = np.sum(cm[i, :]) - tp
        tn = np.sum(cm) - tp - fp - fn
        specificity = tn/(tn+fp)
        
        per_class_metrics.append({
            'Class': class_name,
            'True Positives': tp,
            'True Negatives': tn,
            'False Positives': fp,
            'False Negatives': fn,
            'Precision': class_precision,
            'Recall': class_recall,
            'F1-Score': class_f1,
            'Specificity': specificity
        })
    
    # Save per-class metrics
    pd.DataFrame(per_class_metrics).to_csv(f'{save_dir}/per_class_metrics.csv', index=False)
    
    with open(f'{save_dir}/per_class_metrics.txt', 'w', encoding='utf-8') as f:
        for metrics in per_class_metrics:
            f.write(f"\n{metrics['Class']}:\n")
            f.write(f"True Positives (TP): {metrics['True Positives']}\n")
            f.write(f"True Negatives (TN): {metrics['True Negatives']}\n")
            f.write(f"False Positives (FP): {metrics['False Positives']}\n")
            f.write(f"False Negatives (FN): {metrics['False Negatives']}\n")
            f.write(f"Precision: {metrics['Precision']:.4f}\n")
            f.write(f"Recall: {metrics['Recall']:.4f}\n")
            f.write(f"F1-Score: {metrics['F1-Score']:.4f}\n")
            f.write(f"Specificity: {metrics['Specificity']:.4f}\n")
    
    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'confusion_matrix': cm,
        'confusion_matrix_df': cm_df,
        'per_class_metrics': per_class_metrics
    }

# Inisialisasi K-Fold
n_folds = 5
kfold = KFold(n_splits=n_folds, shuffle=True, random_state=42)

# List untuk menyimpan hasil setiap fold
fold_histories = []
fold_results = []

# K-Fold Cross Validation
for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train)):
    fold_num = fold + 1
    print(f'\nFold {fold_num}/{n_folds}')
    fold_dir = f'fold_results/fold_{fold_num}'
    
    # Split data untuk fold ini
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train_cat[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train_cat[val_idx]
    
    # Build model
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_dnn_model(input_shape)
    
    if fold == 0:
        model.summary()
        # Save model summary to file
        with open('model_summary.txt', 'w', encoding='utf-8') as f:
            from io import StringIO
            summary_string = StringIO()
            model.summary(print_fn=lambda x: summary_string.write(x + '\n'))
            f.write(summary_string.getvalue())
    
    # Training
    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        epochs=50,
        batch_size=32,
        callbacks=get_callbacks(fold_num),
        verbose=1
    )
    
    # Save training history
    pd.DataFrame(history.history).to_csv(f'{fold_dir}/training_history.csv', index=False)
    plot_training_history(history, fold_num, fold_dir)
    
    # Evaluasi pada validation fold
    fold_results.append(
        evaluate_model(model, X_val_fold, y_val_fold, le.classes_, fold_num, fold_dir)
    )
    fold_histories.append(history.history)

# Menghitung dan menyimpan rata-rata metrics dari semua fold
avg_metrics = {
    'accuracy': np.mean([res['accuracy'] for res in fold_results]),
    'precision': np.mean([res['precision'] for res in fold_results]),
    'recall': np.mean([res['recall'] for res in fold_results]),
    'f1': np.mean([res['f1'] for res in fold_results])
}

# Simpan hasil K-Fold
kfold_results_df = pd.DataFrame({
    'Fold': range(1, n_folds + 1),
    'Accuracy': [res['accuracy'] for res in fold_results],
    'Precision': [res['precision'] for res in fold_results],
    'Recall': [res['recall'] for res in fold_results],
    'F1-Score': [res['f1'] for res in fold_results]
})
kfold_results_df.loc[len(kfold_results_df)] = ['Average', 
                                              avg_metrics['accuracy'], 
                                              avg_metrics['precision'], 
                                              avg_metrics['recall'],
                                              avg_metrics['f1']]
kfold_results_df.to_csv('fold_results/kfold_results_summary.csv', index=False)

# Plot hasil K-Fold
plt.figure(figsize=(12, 6))
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
for metric in metrics:
    plt.plot(range(1, n_folds + 1), kfold_results_df[metric][:n_folds], 
             marker='o', label=metric)
plt.title('Model Metrics Across Folds')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.savefig('fold_results/kfold_metrics_comparison.png')
plt.close()

# Final model training dan evaluasi
print("\nTraining final model on complete training set...")
final_model = build_dnn_model(input_shape)
final_history = final_model.fit(
    X_train, y_train_cat,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    callbacks=get_callbacks('final'),
    verbose=1
)

# Save final model results
final_dir = 'fold_results/final_model'
if not os.path.exists(final_dir):
    os.makedirs(final_dir)

# Plot dan save training history untuk model final
plot_training_history(final_history, 'Final', final_dir)
pd.DataFrame(final_history.history).to_csv(f'{final_dir}/training_history.csv', index=False)

# Evaluasi model final pada test set
final_results = evaluate_model(final_model, X_test, y_test_cat, le.classes_, 'Final', final_dir)

# Save final model
final_model.save(f'{final_dir}/final_dnn_model_5class.h5')
# Out:
# Fold 1/5
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 12000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     3,072,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,115,653 (11.89 MB)
#  Trainable params: 3,115,653 (11.89 MB)
#  Non-trainable params: 0 (0.00 B)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5593 - loss: 1.1806
# Epoch 1: val_accuracy improved from -inf to 0.69601, saving model to fold_results/fold_1/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - accuracy: 0.5594 - loss: 1.1802 - val_accuracy: 0.6960 - val_loss: 0.7657 - learning_rate: 0.0010
# Epoch 2/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7061 - loss: 0.7843
# Epoch 2: val_accuracy improved from 0.69601 to 0.69884, saving model to fold_results/fold_1/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7060 - loss: 0.7843 - val_accuracy: 0.6988 - val_loss: 0.7377 - learning_rate: 0.0010
# Epoch 3/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6990 - loss: 0.7359
# Epoch 3: val_accuracy improved from 0.69884 to 0.70054, saving model to fold_results/fold_1/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6990 - loss: 0.7359 - val_accuracy: 0.7005 - val_loss: 0.7437 - learning_rate: 0.0010
# Epoch 4/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7199 - loss: 0.6779
# Epoch 4: val_accuracy improved from 0.70054 to 0.71129, saving model to fold_results/fold_1/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7199 - loss: 0.6779 - val_accuracy: 0.7113 - val_loss: 0.7141 - learning_rate: 0.0010
# Epoch 5/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7415 - loss: 0.6058
# Epoch 5: val_accuracy improved from 0.71129 to 0.71922, saving model to fold_results/fold_1/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7415 - loss: 0.6059 - val_accuracy: 0.7192 - val_loss: 0.6987 - learning_rate: 0.0010
# Epoch 6/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7728 - loss: 0.5437
# Epoch 6: val_accuracy improved from 0.71922 to 0.72969, saving model to fold_results/fold_1/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7728 - loss: 0.5438 - val_accuracy: 0.7297 - val_loss: 0.7207 - learning_rate: 0.0010
# Epoch 7/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7926 - loss: 0.4988
# Epoch 7: val_accuracy did not improve from 0.72969
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7926 - loss: 0.4988 - val_accuracy: 0.7254 - val_loss: 0.8167 - learning_rate: 0.0010
# Epoch 8/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8065 - loss: 0.4560
# Epoch 8: val_accuracy improved from 0.72969 to 0.73196, saving model to fold_results/fold_1/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8065 - loss: 0.4560 - val_accuracy: 0.7320 - val_loss: 0.7630 - learning_rate: 0.0010
# Epoch 9/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8159 - loss: 0.4397
# Epoch 9: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8159 - loss: 0.4397 - val_accuracy: 0.7286 - val_loss: 0.8188 - learning_rate: 0.0010
# Epoch 10/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8232 - loss: 0.4011
# Epoch 10: val_accuracy did not improve from 0.73196
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8232 - loss: 0.4012 - val_accuracy: 0.7243 - val_loss: 0.8047 - learning_rate: 0.0010
# Epoch 11/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8415 - loss: 0.3441
# Epoch 11: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8415 - loss: 0.3441 - val_accuracy: 0.7104 - val_loss: 0.9242 - learning_rate: 5.0000e-04
# Epoch 12/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8453 - loss: 0.3162
# Epoch 12: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8453 - loss: 0.3162 - val_accuracy: 0.7189 - val_loss: 0.8758 - learning_rate: 5.0000e-04
# Epoch 13/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8594 - loss: 0.2797
# Epoch 13: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8594 - loss: 0.2797 - val_accuracy: 0.7249 - val_loss: 1.1198 - learning_rate: 5.0000e-04
# Epoch 14/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8722 - loss: 0.2675
# Epoch 14: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8722 - loss: 0.2675 - val_accuracy: 0.7215 - val_loss: 1.0612 - learning_rate: 5.0000e-04
# Epoch 15/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8708 - loss: 0.2537
# Epoch 15: val_accuracy did not improve from 0.73196
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8708 - loss: 0.2537 - val_accuracy: 0.7187 - val_loss: 1.1130 - learning_rate: 5.0000e-04
# Epoch 16/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8795 - loss: 0.2416
# Epoch 16: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8795 - loss: 0.2416 - val_accuracy: 0.7133 - val_loss: 1.1195 - learning_rate: 2.5000e-04
# Epoch 17/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8846 - loss: 0.2354
# Epoch 17: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8846 - loss: 0.2355 - val_accuracy: 0.7195 - val_loss: 1.2435 - learning_rate: 2.5000e-04
# Epoch 18/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8834 - loss: 0.2257
# Epoch 18: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8834 - loss: 0.2257 - val_accuracy: 0.7150 - val_loss: 1.2548 - learning_rate: 2.5000e-04
# Epoch 19/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8896 - loss: 0.2216
# Epoch 19: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8896 - loss: 0.2216 - val_accuracy: 0.7158 - val_loss: 1.3290 - learning_rate: 2.5000e-04
# Epoch 20/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8937 - loss: 0.2140
# Epoch 20: val_accuracy did not improve from 0.73196
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8938 - loss: 0.2141 - val_accuracy: 0.7136 - val_loss: 1.3691 - learning_rate: 2.5000e-04
# Epoch 21/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9043 - loss: 0.2118
# Epoch 21: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9043 - loss: 0.2118 - val_accuracy: 0.7161 - val_loss: 1.4309 - learning_rate: 1.2500e-04
# Epoch 22/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9051 - loss: 0.2056
# Epoch 22: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9051 - loss: 0.2056 - val_accuracy: 0.7121 - val_loss: 1.4426 - learning_rate: 1.2500e-04
# Epoch 23/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9135 - loss: 0.1899
# Epoch 23: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9135 - loss: 0.1899 - val_accuracy: 0.7102 - val_loss: 1.4609 - learning_rate: 1.2500e-04
# Epoch 24/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9097 - loss: 0.2004
# Epoch 24: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9098 - loss: 0.2003 - val_accuracy: 0.7102 - val_loss: 1.5333 - learning_rate: 1.2500e-04
# Epoch 25/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9218 - loss: 0.1825
# Epoch 25: val_accuracy did not improve from 0.73196
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9218 - loss: 0.1825 - val_accuracy: 0.7107 - val_loss: 1.5325 - learning_rate: 1.2500e-04
# Epoch 26/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9225 - loss: 0.1782
# Epoch 26: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9224 - loss: 0.1782 - val_accuracy: 0.7124 - val_loss: 1.6297 - learning_rate: 6.2500e-05
# Epoch 27/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9229 - loss: 0.1714
# Epoch 27: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9229 - loss: 0.1714 - val_accuracy: 0.7147 - val_loss: 1.6451 - learning_rate: 6.2500e-05
# Epoch 28/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9247 - loss: 0.1689
# Epoch 28: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9247 - loss: 0.1689 - val_accuracy: 0.7136 - val_loss: 1.6402 - learning_rate: 6.2500e-05
# Epoch 29/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9294 - loss: 0.1649
# Epoch 29: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9294 - loss: 0.1650 - val_accuracy: 0.7113 - val_loss: 1.6263 - learning_rate: 6.2500e-05
# Epoch 30/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9275 - loss: 0.1631
# Epoch 30: val_accuracy did not improve from 0.73196
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9275 - loss: 0.1631 - val_accuracy: 0.7144 - val_loss: 1.6900 - learning_rate: 6.2500e-05
# Epoch 31/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9305 - loss: 0.1634
# Epoch 31: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9305 - loss: 0.1634 - val_accuracy: 0.7130 - val_loss: 1.7201 - learning_rate: 3.1250e-05
# Epoch 32/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9361 - loss: 0.1509
# Epoch 32: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9361 - loss: 0.1509 - val_accuracy: 0.7150 - val_loss: 1.7167 - learning_rate: 3.1250e-05
# Epoch 33/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9355 - loss: 0.1527
# Epoch 33: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9355 - loss: 0.1527 - val_accuracy: 0.7116 - val_loss: 1.7226 - learning_rate: 3.1250e-05
# Epoch 34/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9336 - loss: 0.1531
# Epoch 34: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9335 - loss: 0.1531 - val_accuracy: 0.7116 - val_loss: 1.7634 - learning_rate: 3.1250e-05
# Epoch 35/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9350 - loss: 0.1486
# Epoch 35: val_accuracy did not improve from 0.73196
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9350 - loss: 0.1486 - val_accuracy: 0.7144 - val_loss: 1.7964 - learning_rate: 3.1250e-05
# Epoch 36/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9382 - loss: 0.1547
# Epoch 36: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9382 - loss: 0.1547 - val_accuracy: 0.7147 - val_loss: 1.7836 - learning_rate: 1.5625e-05
# Epoch 37/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9395 - loss: 0.1443
# Epoch 37: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9395 - loss: 0.1443 - val_accuracy: 0.7130 - val_loss: 1.7990 - learning_rate: 1.5625e-05
# Epoch 38/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9347 - loss: 0.1491
# Epoch 38: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9347 - loss: 0.1491 - val_accuracy: 0.7133 - val_loss: 1.7831 - learning_rate: 1.5625e-05
# Epoch 39/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9417 - loss: 0.1421
# Epoch 39: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9417 - loss: 0.1421 - val_accuracy: 0.7130 - val_loss: 1.8019 - learning_rate: 1.5625e-05
# Epoch 40/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9381 - loss: 0.1458
# Epoch 40: val_accuracy did not improve from 0.73196
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9381 - loss: 0.1458 - val_accuracy: 0.7127 - val_loss: 1.8176 - learning_rate: 1.5625e-05
# Epoch 41/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9404 - loss: 0.1405
# Epoch 41: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9404 - loss: 0.1405 - val_accuracy: 0.7113 - val_loss: 1.8256 - learning_rate: 1.0000e-05
# Epoch 42/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9450 - loss: 0.1358
# Epoch 42: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9450 - loss: 0.1359 - val_accuracy: 0.7116 - val_loss: 1.8377 - learning_rate: 1.0000e-05
# Epoch 43/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9384 - loss: 0.1460
# Epoch 43: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9384 - loss: 0.1460 - val_accuracy: 0.7110 - val_loss: 1.8427 - learning_rate: 1.0000e-05
# Epoch 44/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9418 - loss: 0.1413
# Epoch 44: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9418 - loss: 0.1413 - val_accuracy: 0.7110 - val_loss: 1.8428 - learning_rate: 1.0000e-05
# Epoch 45/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9368 - loss: 0.1475
# Epoch 45: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9368 - loss: 0.1475 - val_accuracy: 0.7116 - val_loss: 1.8645 - learning_rate: 1.0000e-05
# Epoch 46/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9398 - loss: 0.1394
# Epoch 46: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9398 - loss: 0.1394 - val_accuracy: 0.7124 - val_loss: 1.8670 - learning_rate: 1.0000e-05
# Epoch 47/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9389 - loss: 0.1426
# Epoch 47: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9389 - loss: 0.1426 - val_accuracy: 0.7130 - val_loss: 1.8721 - learning_rate: 1.0000e-05
# Epoch 48/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9396 - loss: 0.1402
# Epoch 48: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9396 - loss: 0.1402 - val_accuracy: 0.7121 - val_loss: 1.8734 - learning_rate: 1.0000e-05
# Epoch 49/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9413 - loss: 0.1448
# Epoch 49: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9413 - loss: 0.1448 - val_accuracy: 0.7130 - val_loss: 1.8811 - learning_rate: 1.0000e-05
# Epoch 50/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9411 - loss: 0.1392
# Epoch 50: val_accuracy did not improve from 0.73196
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9411 - loss: 0.1392 - val_accuracy: 0.7136 - val_loss: 1.8799 - learning_rate: 1.0000e-05
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Fold 2/5
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5374 - loss: 1.2446
# Epoch 1: val_accuracy improved from -inf to 0.69658, saving model to fold_results/fold_2/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.5380 - loss: 1.2430 - val_accuracy: 0.6966 - val_loss: 0.7717 - learning_rate: 0.0010
# Epoch 2/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6920 - loss: 0.7993
# Epoch 2: val_accuracy did not improve from 0.69658
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.6920 - loss: 0.7992 - val_accuracy: 0.6960 - val_loss: 0.7590 - learning_rate: 0.0010
# Epoch 3/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6985 - loss: 0.7444
# Epoch 3: val_accuracy improved from 0.69658 to 0.69686, saving model to fold_results/fold_2/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.6985 - loss: 0.7444 - val_accuracy: 0.6969 - val_loss: 0.7542 - learning_rate: 0.0010
# Epoch 4/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7032 - loss: 0.7084
# Epoch 4: val_accuracy improved from 0.69686 to 0.69799, saving model to fold_results/fold_2/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7032 - loss: 0.7085 - val_accuracy: 0.6980 - val_loss: 0.7366 - learning_rate: 0.0010
# Epoch 5/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7161 - loss: 0.6443
# Epoch 5: val_accuracy improved from 0.69799 to 0.70620, saving model to fold_results/fold_2/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7161 - loss: 0.6444 - val_accuracy: 0.7062 - val_loss: 0.7218 - learning_rate: 0.0010
# Epoch 6/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7373 - loss: 0.5983
# Epoch 6: val_accuracy improved from 0.70620 to 0.71978, saving model to fold_results/fold_2/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7373 - loss: 0.5983 - val_accuracy: 0.7198 - val_loss: 0.7207 - learning_rate: 0.0010
# Epoch 7/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7602 - loss: 0.5431
# Epoch 7: val_accuracy did not improve from 0.71978
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7602 - loss: 0.5431 - val_accuracy: 0.7181 - val_loss: 0.7235 - learning_rate: 0.0010
# Epoch 8/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7734 - loss: 0.5154
# Epoch 8: val_accuracy improved from 0.71978 to 0.72516, saving model to fold_results/fold_2/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.7734 - loss: 0.5154 - val_accuracy: 0.7252 - val_loss: 0.7478 - learning_rate: 0.0010
# Epoch 9/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7885 - loss: 0.4672
# Epoch 9: val_accuracy improved from 0.72516 to 0.73111, saving model to fold_results/fold_2/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.7885 - loss: 0.4672 - val_accuracy: 0.7311 - val_loss: 0.7268 - learning_rate: 0.0010
# Epoch 10/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8109 - loss: 0.4240
# Epoch 10: val_accuracy did not improve from 0.73111
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8109 - loss: 0.4240 - val_accuracy: 0.7189 - val_loss: 0.8023 - learning_rate: 0.0010
# Epoch 11/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8297 - loss: 0.3707
# Epoch 11: val_accuracy did not improve from 0.73111
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8297 - loss: 0.3708 - val_accuracy: 0.7243 - val_loss: 0.8464 - learning_rate: 0.0010
# Epoch 12/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8355 - loss: 0.3392
# Epoch 12: val_accuracy did not improve from 0.73111
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8355 - loss: 0.3391 - val_accuracy: 0.7198 - val_loss: 0.8637 - learning_rate: 5.0000e-04
# Epoch 13/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8502 - loss: 0.2942
# Epoch 13: val_accuracy did not improve from 0.73111
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8502 - loss: 0.2942 - val_accuracy: 0.7271 - val_loss: 0.9971 - learning_rate: 5.0000e-04
# Epoch 14/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8558 - loss: 0.2875
# Epoch 14: val_accuracy did not improve from 0.73111
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8558 - loss: 0.2875 - val_accuracy: 0.7263 - val_loss: 0.9921 - learning_rate: 5.0000e-04
# Epoch 15/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8609 - loss: 0.2878
# Epoch 15: val_accuracy improved from 0.73111 to 0.73167, saving model to fold_results/fold_2/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8609 - loss: 0.2878 - val_accuracy: 0.7317 - val_loss: 1.0305 - learning_rate: 5.0000e-04
# Epoch 16/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8602 - loss: 0.2723
# Epoch 16: val_accuracy did not improve from 0.73167
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8602 - loss: 0.2723 - val_accuracy: 0.7243 - val_loss: 1.0487 - learning_rate: 5.0000e-04
# Epoch 17/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8684 - loss: 0.2597
# Epoch 17: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8684 - loss: 0.2597 - val_accuracy: 0.7226 - val_loss: 1.0771 - learning_rate: 2.5000e-04
# Epoch 18/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8730 - loss: 0.2398
# Epoch 18: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8730 - loss: 0.2399 - val_accuracy: 0.7269 - val_loss: 1.1912 - learning_rate: 2.5000e-04
# Epoch 19/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8777 - loss: 0.2352
# Epoch 19: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8777 - loss: 0.2351 - val_accuracy: 0.7116 - val_loss: 1.1790 - learning_rate: 2.5000e-04
# Epoch 20/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8816 - loss: 0.2245
# Epoch 20: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8816 - loss: 0.2245 - val_accuracy: 0.7212 - val_loss: 1.3224 - learning_rate: 2.5000e-04
# Epoch 21/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8823 - loss: 0.2232
# Epoch 21: val_accuracy did not improve from 0.73167
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8823 - loss: 0.2232 - val_accuracy: 0.7161 - val_loss: 1.2288 - learning_rate: 2.5000e-04
# Epoch 22/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8882 - loss: 0.2186
# Epoch 22: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8881 - loss: 0.2186 - val_accuracy: 0.7153 - val_loss: 1.2932 - learning_rate: 1.2500e-04
# Epoch 23/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8810 - loss: 0.2256
# Epoch 23: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8811 - loss: 0.2255 - val_accuracy: 0.7170 - val_loss: 1.3321 - learning_rate: 1.2500e-04
# Epoch 24/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8921 - loss: 0.2108
# Epoch 24: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8921 - loss: 0.2108 - val_accuracy: 0.7212 - val_loss: 1.3763 - learning_rate: 1.2500e-04
# Epoch 25/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8929 - loss: 0.2053
# Epoch 25: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8929 - loss: 0.2053 - val_accuracy: 0.7175 - val_loss: 1.4173 - learning_rate: 1.2500e-04
# Epoch 26/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8944 - loss: 0.2092
# Epoch 26: val_accuracy did not improve from 0.73167
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8945 - loss: 0.2092 - val_accuracy: 0.7189 - val_loss: 1.4790 - learning_rate: 1.2500e-04
# Epoch 27/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8998 - loss: 0.1994
# Epoch 27: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8998 - loss: 0.1994 - val_accuracy: 0.7189 - val_loss: 1.5060 - learning_rate: 6.2500e-05
# Epoch 28/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9037 - loss: 0.1985
# Epoch 28: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9037 - loss: 0.1985 - val_accuracy: 0.7189 - val_loss: 1.4583 - learning_rate: 6.2500e-05
# Epoch 29/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8999 - loss: 0.2071
# Epoch 29: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8999 - loss: 0.2071 - val_accuracy: 0.7192 - val_loss: 1.5013 - learning_rate: 6.2500e-05
# Epoch 30/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8986 - loss: 0.2008
# Epoch 30: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8986 - loss: 0.2008 - val_accuracy: 0.7178 - val_loss: 1.5150 - learning_rate: 6.2500e-05
# Epoch 31/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9036 - loss: 0.2051
# Epoch 31: val_accuracy did not improve from 0.73167
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9036 - loss: 0.2050 - val_accuracy: 0.7172 - val_loss: 1.4799 - learning_rate: 6.2500e-05
# Epoch 32/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9070 - loss: 0.1889
# Epoch 32: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9070 - loss: 0.1889 - val_accuracy: 0.7189 - val_loss: 1.4952 - learning_rate: 3.1250e-05
# Epoch 33/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9042 - loss: 0.1900
# Epoch 33: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9042 - loss: 0.1901 - val_accuracy: 0.7167 - val_loss: 1.5142 - learning_rate: 3.1250e-05
# Epoch 34/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9088 - loss: 0.1874
# Epoch 34: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9088 - loss: 0.1874 - val_accuracy: 0.7170 - val_loss: 1.5497 - learning_rate: 3.1250e-05
# Epoch 35/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9104 - loss: 0.1880
# Epoch 35: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9103 - loss: 0.1881 - val_accuracy: 0.7170 - val_loss: 1.5625 - learning_rate: 3.1250e-05
# Epoch 36/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9152 - loss: 0.1784
# Epoch 36: val_accuracy did not improve from 0.73167
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9152 - loss: 0.1784 - val_accuracy: 0.7138 - val_loss: 1.5614 - learning_rate: 3.1250e-05
# Epoch 37/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9110 - loss: 0.1862
# Epoch 37: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9110 - loss: 0.1863 - val_accuracy: 0.7107 - val_loss: 1.5453 - learning_rate: 1.5625e-05
# Epoch 38/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9164 - loss: 0.1776
# Epoch 38: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9164 - loss: 0.1776 - val_accuracy: 0.7133 - val_loss: 1.5631 - learning_rate: 1.5625e-05
# Epoch 39/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9160 - loss: 0.1857
# Epoch 39: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9160 - loss: 0.1857 - val_accuracy: 0.7141 - val_loss: 1.5694 - learning_rate: 1.5625e-05
# Epoch 40/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9141 - loss: 0.1875
# Epoch 40: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9141 - loss: 0.1875 - val_accuracy: 0.7141 - val_loss: 1.5712 - learning_rate: 1.5625e-05
# Epoch 41/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9163 - loss: 0.1778
# Epoch 41: val_accuracy did not improve from 0.73167
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9163 - loss: 0.1778 - val_accuracy: 0.7144 - val_loss: 1.5957 - learning_rate: 1.5625e-05
# Epoch 42/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9210 - loss: 0.1769
# Epoch 42: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9210 - loss: 0.1769 - val_accuracy: 0.7124 - val_loss: 1.6006 - learning_rate: 1.0000e-05
# Epoch 43/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9142 - loss: 0.1912
# Epoch 43: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9142 - loss: 0.1911 - val_accuracy: 0.7124 - val_loss: 1.5988 - learning_rate: 1.0000e-05
# Epoch 44/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9192 - loss: 0.1753
# Epoch 44: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9192 - loss: 0.1753 - val_accuracy: 0.7121 - val_loss: 1.6010 - learning_rate: 1.0000e-05
# Epoch 45/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9155 - loss: 0.1793
# Epoch 45: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9155 - loss: 0.1793 - val_accuracy: 0.7113 - val_loss: 1.6031 - learning_rate: 1.0000e-05
# Epoch 46/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9207 - loss: 0.1714
# Epoch 46: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9207 - loss: 0.1714 - val_accuracy: 0.7113 - val_loss: 1.6127 - learning_rate: 1.0000e-05
# Epoch 47/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9147 - loss: 0.1791
# Epoch 47: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9147 - loss: 0.1791 - val_accuracy: 0.7104 - val_loss: 1.6098 - learning_rate: 1.0000e-05
# Epoch 48/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9184 - loss: 0.1745
# Epoch 48: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9183 - loss: 0.1745 - val_accuracy: 0.7116 - val_loss: 1.6215 - learning_rate: 1.0000e-05
# Epoch 49/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9210 - loss: 0.1735
# Epoch 49: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9210 - loss: 0.1735 - val_accuracy: 0.7113 - val_loss: 1.6315 - learning_rate: 1.0000e-05
# Epoch 50/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9197 - loss: 0.1708
# Epoch 50: val_accuracy did not improve from 0.73167
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9197 - loss: 0.1709 - val_accuracy: 0.7110 - val_loss: 1.6317 - learning_rate: 1.0000e-05
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Fold 3/5
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5444 - loss: 1.1735
# Epoch 1: val_accuracy improved from -inf to 0.69346, saving model to fold_results/fold_3/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 13s 25ms/step - accuracy: 0.5448 - loss: 1.1726 - val_accuracy: 0.6935 - val_loss: 0.7852 - learning_rate: 0.0010
# Epoch 2/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6908 - loss: 0.8062
# Epoch 2: val_accuracy improved from 0.69346 to 0.69601, saving model to fold_results/fold_3/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6908 - loss: 0.8062 - val_accuracy: 0.6960 - val_loss: 0.7566 - learning_rate: 0.0010
# Epoch 3/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7107 - loss: 0.7210
# Epoch 3: val_accuracy improved from 0.69601 to 0.69884, saving model to fold_results/fold_3/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7107 - loss: 0.7211 - val_accuracy: 0.6988 - val_loss: 0.7484 - learning_rate: 0.0010
# Epoch 4/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7174 - loss: 0.6797
# Epoch 4: val_accuracy improved from 0.69884 to 0.71554, saving model to fold_results/fold_3/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.7174 - loss: 0.6797 - val_accuracy: 0.7155 - val_loss: 0.7188 - learning_rate: 0.0010
# Epoch 5/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7443 - loss: 0.5997
# Epoch 5: val_accuracy improved from 0.71554 to 0.72177, saving model to fold_results/fold_3/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7443 - loss: 0.5998 - val_accuracy: 0.7218 - val_loss: 0.7150 - learning_rate: 0.0010
# Epoch 6/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7746 - loss: 0.5417
# Epoch 6: val_accuracy improved from 0.72177 to 0.72884, saving model to fold_results/fold_3/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7746 - loss: 0.5417 - val_accuracy: 0.7288 - val_loss: 0.7343 - learning_rate: 0.0010
# Epoch 7/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7822 - loss: 0.5074
# Epoch 7: val_accuracy improved from 0.72884 to 0.73564, saving model to fold_results/fold_3/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7822 - loss: 0.5075 - val_accuracy: 0.7356 - val_loss: 0.7076 - learning_rate: 0.0010
# Epoch 8/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8061 - loss: 0.4502
# Epoch 8: val_accuracy improved from 0.73564 to 0.73762, saving model to fold_results/fold_3/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8061 - loss: 0.4503 - val_accuracy: 0.7376 - val_loss: 0.7369 - learning_rate: 0.0010
# Epoch 9/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8104 - loss: 0.4434
# Epoch 9: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8103 - loss: 0.4435 - val_accuracy: 0.7359 - val_loss: 0.7729 - learning_rate: 0.0010
# Epoch 10/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8194 - loss: 0.4008
# Epoch 10: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8194 - loss: 0.4008 - val_accuracy: 0.7311 - val_loss: 0.8419 - learning_rate: 0.0010
# Epoch 11/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8271 - loss: 0.3820
# Epoch 11: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8270 - loss: 0.3820 - val_accuracy: 0.7269 - val_loss: 0.8174 - learning_rate: 0.0010
# Epoch 12/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8272 - loss: 0.3682
# Epoch 12: val_accuracy did not improve from 0.73762
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8272 - loss: 0.3682 - val_accuracy: 0.7334 - val_loss: 0.8237 - learning_rate: 0.0010
# Epoch 13/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8409 - loss: 0.3252
# Epoch 13: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8409 - loss: 0.3251 - val_accuracy: 0.7291 - val_loss: 0.9121 - learning_rate: 5.0000e-04
# Epoch 14/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8581 - loss: 0.2756
# Epoch 14: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8581 - loss: 0.2756 - val_accuracy: 0.7277 - val_loss: 1.0014 - learning_rate: 5.0000e-04
# Epoch 15/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8571 - loss: 0.2723
# Epoch 15: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8571 - loss: 0.2723 - val_accuracy: 0.7303 - val_loss: 0.9666 - learning_rate: 5.0000e-04
# Epoch 16/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8680 - loss: 0.2500
# Epoch 16: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8680 - loss: 0.2500 - val_accuracy: 0.7325 - val_loss: 1.1238 - learning_rate: 5.0000e-04
# Epoch 17/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8762 - loss: 0.2543
# Epoch 17: val_accuracy did not improve from 0.73762
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8761 - loss: 0.2543 - val_accuracy: 0.7274 - val_loss: 1.0720 - learning_rate: 5.0000e-04
# Epoch 18/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8843 - loss: 0.2322
# Epoch 18: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8843 - loss: 0.2322 - val_accuracy: 0.7269 - val_loss: 1.1574 - learning_rate: 2.5000e-04
# Epoch 19/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8828 - loss: 0.2239
# Epoch 19: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8828 - loss: 0.2239 - val_accuracy: 0.7320 - val_loss: 1.1705 - learning_rate: 2.5000e-04
# Epoch 20/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8871 - loss: 0.2238
# Epoch 20: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8871 - loss: 0.2238 - val_accuracy: 0.7277 - val_loss: 1.1165 - learning_rate: 2.5000e-04
# Epoch 21/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8873 - loss: 0.2221
# Epoch 21: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8873 - loss: 0.2221 - val_accuracy: 0.7286 - val_loss: 1.2923 - learning_rate: 2.5000e-04
# Epoch 22/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8968 - loss: 0.2067
# Epoch 22: val_accuracy did not improve from 0.73762
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8968 - loss: 0.2067 - val_accuracy: 0.7223 - val_loss: 1.3510 - learning_rate: 2.5000e-04
# Epoch 23/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8973 - loss: 0.2008
# Epoch 23: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8973 - loss: 0.2008 - val_accuracy: 0.7212 - val_loss: 1.3878 - learning_rate: 1.2500e-04
# Epoch 24/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8970 - loss: 0.2082
# Epoch 24: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8970 - loss: 0.2082 - val_accuracy: 0.7229 - val_loss: 1.3646 - learning_rate: 1.2500e-04
# Epoch 25/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9003 - loss: 0.2030
# Epoch 25: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9003 - loss: 0.2030 - val_accuracy: 0.7175 - val_loss: 1.3684 - learning_rate: 1.2500e-04
# Epoch 26/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9034 - loss: 0.1996
# Epoch 26: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9034 - loss: 0.1996 - val_accuracy: 0.7204 - val_loss: 1.3753 - learning_rate: 1.2500e-04
# Epoch 27/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9022 - loss: 0.1916
# Epoch 27: val_accuracy did not improve from 0.73762
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9022 - loss: 0.1916 - val_accuracy: 0.7172 - val_loss: 1.3398 - learning_rate: 1.2500e-04
# Epoch 28/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9078 - loss: 0.1942
# Epoch 28: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9078 - loss: 0.1942 - val_accuracy: 0.7192 - val_loss: 1.3840 - learning_rate: 6.2500e-05
# Epoch 29/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9120 - loss: 0.1863
# Epoch 29: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9120 - loss: 0.1864 - val_accuracy: 0.7246 - val_loss: 1.4376 - learning_rate: 6.2500e-05
# Epoch 30/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9125 - loss: 0.1827
# Epoch 30: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9125 - loss: 0.1828 - val_accuracy: 0.7223 - val_loss: 1.4260 - learning_rate: 6.2500e-05
# Epoch 31/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9146 - loss: 0.1816
# Epoch 31: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9146 - loss: 0.1816 - val_accuracy: 0.7212 - val_loss: 1.4414 - learning_rate: 6.2500e-05
# Epoch 32/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9144 - loss: 0.1831
# Epoch 32: val_accuracy did not improve from 0.73762
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9144 - loss: 0.1831 - val_accuracy: 0.7215 - val_loss: 1.4952 - learning_rate: 6.2500e-05
# Epoch 33/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9225 - loss: 0.1767
# Epoch 33: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9225 - loss: 0.1767 - val_accuracy: 0.7229 - val_loss: 1.4980 - learning_rate: 3.1250e-05
# Epoch 34/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9201 - loss: 0.1807
# Epoch 34: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9201 - loss: 0.1806 - val_accuracy: 0.7218 - val_loss: 1.4844 - learning_rate: 3.1250e-05
# Epoch 35/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9189 - loss: 0.1748
# Epoch 35: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9189 - loss: 0.1748 - val_accuracy: 0.7218 - val_loss: 1.5051 - learning_rate: 3.1250e-05
# Epoch 36/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9215 - loss: 0.1769
# Epoch 36: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9215 - loss: 0.1769 - val_accuracy: 0.7198 - val_loss: 1.4940 - learning_rate: 3.1250e-05
# Epoch 37/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9236 - loss: 0.1710
# Epoch 37: val_accuracy did not improve from 0.73762
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9236 - loss: 0.1711 - val_accuracy: 0.7192 - val_loss: 1.4839 - learning_rate: 3.1250e-05
# Epoch 38/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9233 - loss: 0.1694
# Epoch 38: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9233 - loss: 0.1694 - val_accuracy: 0.7204 - val_loss: 1.4868 - learning_rate: 1.5625e-05
# Epoch 39/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9247 - loss: 0.1690
# Epoch 39: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9247 - loss: 0.1690 - val_accuracy: 0.7192 - val_loss: 1.4945 - learning_rate: 1.5625e-05
# Epoch 40/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9278 - loss: 0.1587
# Epoch 40: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9278 - loss: 0.1587 - val_accuracy: 0.7195 - val_loss: 1.5097 - learning_rate: 1.5625e-05
# Epoch 41/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9286 - loss: 0.1630
# Epoch 41: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9286 - loss: 0.1630 - val_accuracy: 0.7195 - val_loss: 1.5050 - learning_rate: 1.5625e-05
# Epoch 42/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9265 - loss: 0.1641
# Epoch 42: val_accuracy did not improve from 0.73762
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9265 - loss: 0.1641 - val_accuracy: 0.7187 - val_loss: 1.5099 - learning_rate: 1.5625e-05
# Epoch 43/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9258 - loss: 0.1692
# Epoch 43: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9258 - loss: 0.1692 - val_accuracy: 0.7192 - val_loss: 1.5139 - learning_rate: 1.0000e-05
# Epoch 44/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9242 - loss: 0.1664
# Epoch 44: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9242 - loss: 0.1664 - val_accuracy: 0.7181 - val_loss: 1.5134 - learning_rate: 1.0000e-05
# Epoch 45/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9257 - loss: 0.1660
# Epoch 45: val_accuracy did not improve from 0.73762
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9257 - loss: 0.1659 - val_accuracy: 0.7170 - val_loss: 1.5025 - learning_rate: 1.0000e-05
# Epoch 46/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9269 - loss: 0.1590
# Epoch 46: val_accuracy did not improve from 0.73762
# ...
# Epoch 1/50
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5338 - loss: 1.2249
# Epoch 1: val_accuracy improved from -inf to 0.72177, saving model to fold_results/fold_final/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.5340 - loss: 1.2244 - val_accuracy: 0.7218 - val_loss: 0.7386 - learning_rate: 0.0010
# Epoch 2/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6933 - loss: 0.7970
# Epoch 2: val_accuracy improved from 0.72177 to 0.72233, saving model to fold_results/fold_final/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.6932 - loss: 0.7970 - val_accuracy: 0.7223 - val_loss: 0.7311 - learning_rate: 0.0010
# Epoch 3/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7009 - loss: 0.7520
# Epoch 3: val_accuracy improved from 0.72233 to 0.72318, saving model to fold_results/fold_final/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7009 - loss: 0.7519 - val_accuracy: 0.7232 - val_loss: 0.7162 - learning_rate: 0.0010
# Epoch 4/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7088 - loss: 0.7092
# Epoch 4: val_accuracy improved from 0.72318 to 0.72856, saving model to fold_results/fold_final/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7088 - loss: 0.7092 - val_accuracy: 0.7286 - val_loss: 0.6965 - learning_rate: 0.0010
# Epoch 5/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7267 - loss: 0.6458
# Epoch 5: val_accuracy improved from 0.72856 to 0.73677, saving model to fold_results/fold_final/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7267 - loss: 0.6459 - val_accuracy: 0.7368 - val_loss: 0.6847 - learning_rate: 0.0010
# Epoch 6/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7499 - loss: 0.5980
# Epoch 6: val_accuracy improved from 0.73677 to 0.74243, saving model to fold_results/fold_final/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.7499 - loss: 0.5979 - val_accuracy: 0.7424 - val_loss: 0.6925 - learning_rate: 0.0010
# Epoch 7/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7907 - loss: 0.5142
# Epoch 7: val_accuracy improved from 0.74243 to 0.75149, saving model to fold_results/fold_final/best_dnn_model_5class.keras
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.7906 - loss: 0.5143 - val_accuracy: 0.7515 - val_loss: 0.7143 - learning_rate: 0.0010
# Epoch 8/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8041 - loss: 0.4662
# Epoch 8: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8041 - loss: 0.4663 - val_accuracy: 0.7322 - val_loss: 0.7176 - learning_rate: 0.0010
# Epoch 9/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8041 - loss: 0.4582
# Epoch 9: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8041 - loss: 0.4582 - val_accuracy: 0.7413 - val_loss: 0.7871 - learning_rate: 0.0010
# Epoch 10/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8236 - loss: 0.3952
# Epoch 10: val_accuracy did not improve from 0.75149
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8236 - loss: 0.3953 - val_accuracy: 0.7373 - val_loss: 0.7770 - learning_rate: 0.0010
# Epoch 11/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8364 - loss: 0.3474
# Epoch 11: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8364 - loss: 0.3474 - val_accuracy: 0.7458 - val_loss: 0.9557 - learning_rate: 5.0000e-04
# Epoch 12/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8532 - loss: 0.3076
# Epoch 12: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8532 - loss: 0.3076 - val_accuracy: 0.7351 - val_loss: 0.9762 - learning_rate: 5.0000e-04
# Epoch 13/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8616 - loss: 0.2914
# Epoch 13: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8616 - loss: 0.2914 - val_accuracy: 0.7308 - val_loss: 1.0011 - learning_rate: 5.0000e-04
# Epoch 14/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8618 - loss: 0.2929
# Epoch 14: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8618 - loss: 0.2929 - val_accuracy: 0.7339 - val_loss: 0.9996 - learning_rate: 5.0000e-04
# Epoch 15/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8732 - loss: 0.2672
# Epoch 15: val_accuracy did not improve from 0.75149
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8732 - loss: 0.2672 - val_accuracy: 0.7311 - val_loss: 1.0896 - learning_rate: 5.0000e-04
# Epoch 16/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8749 - loss: 0.2627
# Epoch 16: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8749 - loss: 0.2627 - val_accuracy: 0.7325 - val_loss: 1.0769 - learning_rate: 2.5000e-04
# Epoch 17/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8754 - loss: 0.2482
# Epoch 17: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8754 - loss: 0.2482 - val_accuracy: 0.7354 - val_loss: 1.1813 - learning_rate: 2.5000e-04
# Epoch 18/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8829 - loss: 0.2362
# Epoch 18: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8829 - loss: 0.2362 - val_accuracy: 0.7348 - val_loss: 1.2413 - learning_rate: 2.5000e-04
# Epoch 19/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8915 - loss: 0.2242
# Epoch 19: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.8915 - loss: 0.2242 - val_accuracy: 0.7359 - val_loss: 1.3735 - learning_rate: 2.5000e-04
# Epoch 20/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8964 - loss: 0.2117
# Epoch 20: val_accuracy did not improve from 0.75149
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8964 - loss: 0.2117 - val_accuracy: 0.7314 - val_loss: 1.2872 - learning_rate: 2.5000e-04
# Epoch 21/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8979 - loss: 0.2135
# Epoch 21: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8979 - loss: 0.2135 - val_accuracy: 0.7359 - val_loss: 1.3365 - learning_rate: 1.2500e-04
# Epoch 22/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9027 - loss: 0.2014
# Epoch 22: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9027 - loss: 0.2014 - val_accuracy: 0.7314 - val_loss: 1.4056 - learning_rate: 1.2500e-04
# Epoch 23/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9088 - loss: 0.1929
# Epoch 23: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9088 - loss: 0.1929 - val_accuracy: 0.7328 - val_loss: 1.4174 - learning_rate: 1.2500e-04
# Epoch 24/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9070 - loss: 0.1971
# Epoch 24: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9070 - loss: 0.1970 - val_accuracy: 0.7305 - val_loss: 1.4641 - learning_rate: 1.2500e-04
# Epoch 25/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9144 - loss: 0.1827
# Epoch 25: val_accuracy did not improve from 0.75149
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9144 - loss: 0.1827 - val_accuracy: 0.7274 - val_loss: 1.4714 - learning_rate: 1.2500e-04
# Epoch 26/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9182 - loss: 0.1774
# Epoch 26: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9182 - loss: 0.1774 - val_accuracy: 0.7215 - val_loss: 1.4758 - learning_rate: 6.2500e-05
# Epoch 27/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9201 - loss: 0.1793
# Epoch 27: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9201 - loss: 0.1793 - val_accuracy: 0.7246 - val_loss: 1.5301 - learning_rate: 6.2500e-05
# Epoch 28/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9206 - loss: 0.1759
# Epoch 28: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9206 - loss: 0.1759 - val_accuracy: 0.7269 - val_loss: 1.5424 - learning_rate: 6.2500e-05
# Epoch 29/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9268 - loss: 0.1636
# Epoch 29: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9268 - loss: 0.1636 - val_accuracy: 0.7229 - val_loss: 1.5046 - learning_rate: 6.2500e-05
# Epoch 30/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9250 - loss: 0.1700
# Epoch 30: val_accuracy did not improve from 0.75149
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9250 - loss: 0.1700 - val_accuracy: 0.7206 - val_loss: 1.5286 - learning_rate: 6.2500e-05
# Epoch 31/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9267 - loss: 0.1606
# Epoch 31: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9267 - loss: 0.1606 - val_accuracy: 0.7229 - val_loss: 1.5687 - learning_rate: 3.1250e-05
# Epoch 32/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9285 - loss: 0.1603
# Epoch 32: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9285 - loss: 0.1603 - val_accuracy: 0.7252 - val_loss: 1.6142 - learning_rate: 3.1250e-05
# Epoch 33/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9245 - loss: 0.1657
# Epoch 33: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9245 - loss: 0.1657 - val_accuracy: 0.7240 - val_loss: 1.5965 - learning_rate: 3.1250e-05
# Epoch 34/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9318 - loss: 0.1602
# Epoch 34: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9318 - loss: 0.1603 - val_accuracy: 0.7249 - val_loss: 1.5992 - learning_rate: 3.1250e-05
# Epoch 35/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9304 - loss: 0.1556
# Epoch 35: val_accuracy did not improve from 0.75149
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9304 - loss: 0.1556 - val_accuracy: 0.7223 - val_loss: 1.5953 - learning_rate: 3.1250e-05
# Epoch 36/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9307 - loss: 0.1583
# Epoch 36: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9307 - loss: 0.1583 - val_accuracy: 0.7229 - val_loss: 1.6206 - learning_rate: 1.5625e-05
# Epoch 37/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9349 - loss: 0.1495
# Epoch 37: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9349 - loss: 0.1496 - val_accuracy: 0.7209 - val_loss: 1.6349 - learning_rate: 1.5625e-05
# Epoch 38/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9338 - loss: 0.1565
# Epoch 38: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9338 - loss: 0.1565 - val_accuracy: 0.7226 - val_loss: 1.6570 - learning_rate: 1.5625e-05
# Epoch 39/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9357 - loss: 0.1477
# Epoch 39: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9357 - loss: 0.1477 - val_accuracy: 0.7226 - val_loss: 1.6789 - learning_rate: 1.5625e-05
# Epoch 40/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9351 - loss: 0.1464
# Epoch 40: val_accuracy did not improve from 0.75149
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-05.
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9351 - loss: 0.1464 - val_accuracy: 0.7201 - val_loss: 1.6841 - learning_rate: 1.5625e-05
# Epoch 41/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9326 - loss: 0.1544
# Epoch 41: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9326 - loss: 0.1544 - val_accuracy: 0.7204 - val_loss: 1.6977 - learning_rate: 1.0000e-05
# Epoch 42/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9345 - loss: 0.1481
# Epoch 42: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9345 - loss: 0.1481 - val_accuracy: 0.7209 - val_loss: 1.7074 - learning_rate: 1.0000e-05
# Epoch 43/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9353 - loss: 0.1461
# Epoch 43: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9353 - loss: 0.1461 - val_accuracy: 0.7209 - val_loss: 1.7108 - learning_rate: 1.0000e-05
# Epoch 44/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9408 - loss: 0.1472
# Epoch 44: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9408 - loss: 0.1472 - val_accuracy: 0.7206 - val_loss: 1.7054 - learning_rate: 1.0000e-05
# Epoch 45/50
# 441/442 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9356 - loss: 0.1486
# Epoch 45: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9356 - loss: 0.1486 - val_accuracy: 0.7206 - val_loss: 1.7112 - learning_rate: 1.0000e-05
# Epoch 46/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9401 - loss: 0.1446
# Epoch 46: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.9401 - loss: 0.1446 - val_accuracy: 0.7215 - val_loss: 1.7184 - learning_rate: 1.0000e-05
# Epoch 47/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9336 - loss: 0.1453
# Epoch 47: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9336 - loss: 0.1453 - val_accuracy: 0.7218 - val_loss: 1.7299 - learning_rate: 1.0000e-05
# Epoch 48/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9374 - loss: 0.1476
# Epoch 48: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9374 - loss: 0.1476 - val_accuracy: 0.7212 - val_loss: 1.7377 - learning_rate: 1.0000e-05
# Epoch 49/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9406 - loss: 0.1436
# Epoch 49: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9406 - loss: 0.1436 - val_accuracy: 0.7204 - val_loss: 1.7425 - learning_rate: 1.0000e-05
# Epoch 50/50
# 440/442 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9410 - loss: 0.1380
# Epoch 50: val_accuracy did not improve from 0.75149
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9410 - loss: 0.1380 - val_accuracy: 0.7209 - val_loss: 1.7596 - learning_rate: 1.0000e-05
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def display_fold_results(fold_num, metrics, cm, class_names, history):
    """
    Fungsi untuk menampilkan hasil evaluasi setiap fold
    """
    print(f"\n{'='*50}")
    print(f"HASIL EVALUASI FOLD {fold_num}")
    print(f"{'='*50}")
    
    # Tampilkan metrics utama
    print("\nMetrics Utama:")
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print(f"Precision: {metrics['precision']:.4f}")
    print(f"Recall: {metrics['recall']:.4f}")
    print(f"F1-Score: {metrics['f1']:.4f}")
    
    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title(f'Confusion Matrix - Fold {fold_num}')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Plot training history
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    # Plot accuracy
    ax1.plot(history['accuracy'])
    ax1.plot(history['val_accuracy'])
    ax1.set_title(f'Model Accuracy - Fold {fold_num}')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['Train', 'Validation'])
    
    # Plot loss
    ax2.plot(history['loss'])
    ax2.plot(history['val_loss'])
    ax2.set_title(f'Model Loss - Fold {fold_num}')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend(['Train', 'Validation'])
    
    plt.tight_layout()
    plt.show()
    
    # Tampilkan metrics per kelas
    #print("\nMetrics per Kelas:")
    #for metrics in per_class_metrics:
        #print(f"\nKelas: {metrics['Class']}")
        #print(f"True Positives (TP): {metrics['True Positives']}")
        #print(f"True Negatives (TN): {metrics['True Negatives']}")
        #print(f"False Positives (FP): {metrics['False Positives']}")
        #print(f"False Negatives (FN): {metrics['False Negatives']}")
        #print(f"Precision: {metrics['Precision']:.4f}")
        #print(f"Recall: {metrics['Recall']:.4f}")
        #print(f"F1-Score: {metrics['F1-Score']:.4f}")
        #print(f"Specificity: {metrics['Specificity']:.4f}")

# Dalam loop K-Fold, tambahkan:
for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train)):
    fold_num = fold + 1
    print(f'\nMulai pelatihan Fold {fold_num}/{n_folds}')
    
    # ... kode training model ...
    
    # Setelah evaluasi, tampilkan hasil
    fold_metrics = evaluate_model(model, X_val_fold, y_val_fold, le.classes_, fold_num, fold_dir)
    display_fold_results(fold_num, 
                        fold_metrics,
                        fold_metrics['confusion_matrix'],
                        le.classes_,
                        history.history)
    
    fold_results.append(fold_metrics)
    fold_histories.append(history.history)

# Setelah semua fold selesai, tampilkan ringkasan
print("\n" + "="*50)
print("RINGKASAN HASIL K-FOLD CROSS VALIDATION")
print("="*50)

# Tampilkan tabel hasil
print("\nHasil per Fold:")
print(kfold_results_df.to_string(index=False))

# Plot perbandingan metrics antar fold
plt.figure(figsize=(12, 6))
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
for metric in metrics:
    plt.plot(range(1, n_folds + 1), 
             kfold_results_df[metric][:n_folds], 
             marker='o', 
             label=metric)
plt.title('Perbandingan Metrics Antar Fold')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()

# Tampilkan rata-rata dan standar deviasi
print("\nRata-rata dan Standar Deviasi Metrics:")
metrics_mean = kfold_results_df.iloc[:-1][metrics].mean()
metrics_std = kfold_results_df.iloc[:-1][metrics].std()

for metric in metrics:
    print(f"{metric}:")
    print(f"  Mean: {metrics_mean[metric]:.4f}")
    print(f"  Std:  {metrics_std[metric]:.4f}")

# Box plot untuk visualisasi distribusi metrics
plt.figure(figsize=(10, 6))
kfold_results_df.iloc[:-1][metrics].boxplot()
plt.title('Distribusi Metrics Across Folds')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# Untuk model final
print("\n" + "="*50)
print("HASIL MODEL FINAL")
print("="*50)

final_results = evaluate_model(final_model, X_test, y_test_cat, le.classes_, 'Final', final_dir)
display_fold_results('Final', 
                    final_results,
                    final_results['confusion_matrix'],
                    le.classes_,
                    final_history.history)
# Out:
# Mulai pelatihan Fold 1/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 1
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.7271
# Precision: 0.7134
# Recall: 0.7271
# F1-Score: 0.7114
# Mulai pelatihan Fold 2/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 2
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.7271
# Precision: 0.7134
# Recall: 0.7271
# F1-Score: 0.7114
# Mulai pelatihan Fold 3/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 3
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.7271
# Precision: 0.7134
# Recall: 0.7271
# F1-Score: 0.7114
# Mulai pelatihan Fold 4/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 4
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.7271
# Precision: 0.7134
# Recall: 0.7271
# F1-Score: 0.7114
# Mulai pelatihan Fold 5/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 5
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.7271
# Precision: 0.7134
# Recall: 0.7271
# F1-Score: 0.7114
# ==================================================
# RINGKASAN HASIL K-FOLD CROSS VALIDATION
# ==================================================
#
# Hasil per Fold:
#    Fold  Accuracy  Precision   Recall  F1-Score
#       1  0.713558   0.702074 0.713558  0.699499
#       2  0.711010   0.698287 0.711010  0.699781
#       3  0.718370   0.706281 0.718370  0.703265
#       4  0.724031   0.707310 0.724031  0.709440
#       5  0.727067   0.713409 0.727067  0.711371
# Average  0.718807   0.705472 0.718807  0.704671
# Rata-rata dan Standar Deviasi Metrics:
# Accuracy:
#   Mean: 0.7188
#   Std:  0.0068
# Precision:
#   Mean: 0.7055
#   Std:  0.0057
# Recall:
#   Mean: 0.7188
#   Std:  0.0068
# F1-Score:
#   Mean: 0.7047
#   Std:  0.0055
# ==================================================
# HASIL MODEL FINAL
# ==================================================
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ==================================================
# HASIL EVALUASI FOLD Final
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.7170
# Precision: 0.7084
# Recall: 0.7170
# F1-Score: 0.7077
