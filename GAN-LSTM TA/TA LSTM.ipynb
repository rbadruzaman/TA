# %% [markdown]
# # IMPORT DATA

# %% [markdown]
# Superclasses enumerated by dataset description are as follows:
# ```
# Records | Superclass | Description
# 9528 | NORM | Normal ECG
# 5486 | MI | Myocardial Infarction
# 5250 | STTC | ST/T Change
# 4907 | CD | Conduction Disturbance
# 2655 | HYP | Hypertrophy
# ```

# %%
import os
import ast
import wfdb

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow.keras as keras

sns.set_style('darkgrid')

# %% [markdown]
# ## DATA LOADING

# %%
PATH_TO_DATA = 'D:\SMTR 7\Koding\Skripsi\ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3'

# Load data
ECG_df = pd.read_csv(os.path.join(PATH_TO_DATA, 'ptbxl_database.csv'), index_col='ecg_id')
ECG_df.scp_codes = ECG_df.scp_codes.apply(lambda x: ast.literal_eval(x))
ECG_df.patient_id = ECG_df.patient_id.astype(int)
ECG_df.nurse = ECG_df.nurse.astype('Int64')
ECG_df.site = ECG_df.site.astype('Int64')
ECG_df.validated_by = ECG_df.validated_by.astype('Int64')

# Load SCP statements
SCP_df = pd.read_csv(os.path.join(PATH_TO_DATA, 'scp_statements.csv'), index_col=0)
SCP_df = SCP_df[SCP_df.diagnostic == 1]

ECG_df
# Out:
#         patient_id    age  sex  height  weight  nurse  site      device  \
# ecg_id
# 1            15709   56.0    1     NaN    63.0      2     0   CS-12   E
# 2            13243   19.0    0     NaN    70.0      2     0   CS-12   E
# 3            20372   37.0    1     NaN    69.0      2     0   CS-12   E
# 4            17014   24.0    0     NaN    82.0      2     0   CS-12   E
# 5            17448   19.0    1     NaN    70.0      2     0   CS-12   E
# ...            ...    ...  ...     ...     ...    ...   ...         ...
# 21833        17180   67.0    1     NaN     NaN      1     2  AT-60    3
# 21834        20703  300.0    0     NaN     NaN      1     2  AT-60    3
# 21835        19311   59.0    1     NaN     NaN      1     2  AT-60    3
# 21836         8873   64.0    1     NaN     NaN      1     2  AT-60    3
# 21837        11744   68.0    0     NaN     NaN      1     2  AT-60    3
#
#              recording_date  \
# ecg_id
# 1       1984-11-09 09:17:34
# 2       1984-11-14 12:55:37
# 3       1984-11-15 12:49:10
# 4       1984-11-15 13:44:57
# 5       1984-11-17 10:43:15
# ...                     ...
# 21833   2001-05-31 09:14:35
# 21834   2001-06-05 11:33:39
# 21835   2001-06-08 10:30:27
# 21836   2001-06-09 18:21:49
# 21837   2001-06-11 16:43:01
#
#                                                    report  ...  \
# ecg_id                                                     ...
# 1                  sinusrhythmus periphere niederspannung  ...
# 2                     sinusbradykardie sonst normales ekg  ...
# 3                              sinusrhythmus normales ekg  ...
# 4                              sinusrhythmus normales ekg  ...
# 5                              sinusrhythmus normales ekg  ...
# ...                                                   ...  ...
# 21833   ventrikulÄre extrasystole(n) sinustachykardie ...  ...
# 21834   sinusrhythmus lagetyp normal qrs(t) abnorm    ...  ...
# 21835   sinusrhythmus lagetyp normal t abnorm in anter...  ...
# 21836   supraventrikulÄre extrasystole(n) sinusrhythmu...  ...
# 21837   sinusrhythmus p-sinistrocardiale lagetyp norma...  ...
#
#        validated_by_human  baseline_drift static_noise burst_noise  \
# ecg_id
# 1                    True             NaN    , I-V1,           NaN
# 2                    True             NaN          NaN         NaN
# 3                    True             NaN          NaN         NaN
# 4                    True    , II,III,AVF          NaN         NaN
# 5                    True   , III,AVR,AVF          NaN         NaN
# ...                   ...             ...          ...         ...
# 21833                True             NaN   , alles,           NaN
# 21834                True             NaN          NaN         NaN
# 21835                True             NaN   , I-AVR,           NaN
# 21836                True             NaN          NaN         NaN
# 21837                True             NaN   , I-AVL,           NaN
#
#         electrodes_problems  extra_beats  pacemaker  strat_fold  \
# ecg_id
# 1                       NaN          NaN        NaN           3
# 2                       NaN          NaN        NaN           2
# 3                       NaN          NaN        NaN           5
# 4                       NaN          NaN        NaN           3
# 5                       NaN          NaN        NaN           4
# ...                     ...          ...        ...         ...
# 21833                   NaN          1ES        NaN           7
# 21834                   NaN          NaN        NaN           4
# 21835                   NaN          NaN        NaN           2
# 21836                   NaN         SVES        NaN           8
# 21837                   NaN          NaN        NaN           9
#
#                       filename_lr                filename_hr
# ecg_id
# 1       records100/00000/00001_lr  records500/00000/00001_hr
# 2       records100/00000/00002_lr  records500/00000/00002_hr
# 3       records100/00000/00003_lr  records500/00000/00003_hr
# 4       records100/00000/00004_lr  records500/00000/00004_hr
# 5       records100/00000/00005_lr  records500/00000/00005_hr
# ...                           ...                        ...
# 21833   records100/21000/21833_lr  records500/21000/21833_hr
# 21834   records100/21000/21834_lr  records500/21000/21834_hr
# 21835   records100/21000/21835_lr  records500/21000/21835_hr
# 21836   records100/21000/21836_lr  records500/21000/21836_hr
# 21837   records100/21000/21837_lr  records500/21000/21837_hr
#
# [21799 rows x 27 columns]

# %%
# Get diagnostics subclass
def diagnostic_subclass(scp):
    res = set()
    for k in scp.keys():
        if k in SCP_df.index:
            res.add(SCP_df.loc[k].diagnostic_subclass)
    return list(res)
                    
ECG_df['scp_subclasses'] = ECG_df.scp_codes.apply(diagnostic_subclass)

# %% [markdown]
# ## Filtering

# %%
# Membuat list subclass yang diinginkan
selected_subclasses = ['NORM', 'PMI', 'LMI', 'AMI', 'IMI']

# Melakukan filtering
filtered_ECG_df = ECG_df[ECG_df['scp_subclasses'].apply(lambda x: any(subclass in x for subclass in selected_subclasses))]

# %%
filtered_ECG_df.shape
# Out:
# (14982, 28)

# %%
# Menghitung jumlah data untuk setiap subclass
subclass_counts = {}
for subclass in selected_subclasses:
    count = len(filtered_ECG_df[filtered_ECG_df['scp_subclasses'].apply(lambda x: subclass in x)])
    subclass_counts[subclass] = count

# Membuat pie chart
plt.figure(figsize=(10, 8))
plt.pie(subclass_counts.values(), 
        labels=subclass_counts.keys(),
        autopct='%1.1f%%',
        startangle=90)
plt.title('Distribusi Data ECG berdasarkan Subclass')

# Menambahkan legend
plt.legend(title="Subclass", 
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.axis('equal')
plt.show()

# Menampilkan jumlah data dalam bentuk tabel
print("\nJumlah data untuk setiap subclass:")
for subclass, count in subclass_counts.items():
    print(f"{subclass}: {count} data")

print(f"\nTotal keseluruhan data: {sum(subclass_counts.values())} data")
# Out:
# Jumlah data untuk setiap subclass:
# NORM: 9514 data
# PMI: 17 data
# LMI: 201 data
# AMI: 3078 data
# IMI: 3271 data
#
# Total keseluruhan data: 16081 data

# %% [markdown]
# ## Load RawData

# %%
def load_raw_data(df, sampling_rate, path):
    if sampling_rate == 100:
        data = [wfdb.rdsamp(os.path.join(path, f)) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(os.path.join(path, f)) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

sampling_rate = 100

ECG_data = load_raw_data(filtered_ECG_df, sampling_rate, PATH_TO_DATA)

ECG_data.shape
# Out:
# (14982, 1000, 12)

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# ## Fake Data using GAN

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Memisahkan data PMI dan LMI
pmi_data = ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'PMI' in x)]
lmi_data = ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'LMI' in x)]

# Fungsi untuk membagi data
def split_data(data, test_size=0.2):
    n_samples = len(data)
    n_test = int(n_samples * test_size)
    
    indices = np.random.permutation(n_samples)
    test_idx = indices[:n_test]
    train_idx = indices[n_test:]
    
    return data[train_idx], data[test_idx]

# Membagi data menjadi train dan test
pmi_train, pmi_test = split_data(pmi_data)
lmi_train, lmi_test = split_data(lmi_data)

# Preprocessing
def preprocess_data(data):
    data = (data - np.mean(data)) / np.std(data)
    return data.reshape(-1, data.shape[1], 1)

# Preprocess data train dan test
pmi_train_processed = preprocess_data(pmi_train)
pmi_test_processed = preprocess_data(pmi_test)
lmi_train_processed = preprocess_data(lmi_train)
lmi_test_processed = preprocess_data(lmi_test)

# Print info shape data
print("Shape PMI train:", pmi_train_processed.shape)
print("Shape LMI train:", lmi_train_processed.shape)

# Generator model
def build_generator():
    model = keras.Sequential([
        keras.layers.Dense(250 * 4, input_shape=(100,)),
        keras.layers.Reshape((250, 4)),
        
        keras.layers.Conv1D(128, kernel_size=3, padding='same'),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(alpha=0.2),
        
        keras.layers.UpSampling1D(2),
        keras.layers.Conv1D(64, kernel_size=3, padding='same'),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(alpha=0.2),
        
        keras.layers.UpSampling1D(2),
        keras.layers.Conv1D(32, kernel_size=3, padding='same'),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(alpha=0.2),
        
        keras.layers.Conv1D(1, kernel_size=3, padding='same', activation='tanh')
    ])
    return model

# Discriminator model
def build_discriminator():
    model = keras.Sequential([
        keras.layers.Conv1D(64, kernel_size=3, strides=2, padding='same', 
                           input_shape=(1000, 1)),
        keras.layers.LeakyReLU(alpha=0.2),
        keras.layers.Dropout(0.3),
        
        keras.layers.Conv1D(128, kernel_size=3, strides=2, padding='same'),
        keras.layers.LeakyReLU(alpha=0.2),
        keras.layers.Dropout(0.3),
        
        keras.layers.Flatten(),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

# Fungsi training
def train_gan(generator, discriminator, train_data, target_samples=3000, epochs=500, batch_size=16):
    # Optimizers
    generator_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
    
    # Loss function
    cross_entropy = tf.keras.losses.BinaryCrossentropy()
    
    @tf.function
    def train_step(real_signals):
        batch_size = tf.shape(real_signals)[0]
        noise = tf.random.normal([batch_size, 100])
        
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            generated_signals = generator(noise, training=True)
            
            real_output = discriminator(real_signals, training=True)
            fake_output = discriminator(generated_signals, training=True)
            
            gen_loss = cross_entropy(tf.ones_like(fake_output), fake_output)
            real_loss = cross_entropy(tf.ones_like(real_output), real_output)
            fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
            disc_loss = real_loss + fake_loss
            
        gen_gradients = gen_tape.gradient(gen_loss, generator.trainable_variables)
        disc_gradients = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
        
        generator_optimizer.apply_gradients(zip(gen_gradients, generator.trainable_variables))
        discriminator_optimizer.apply_gradients(zip(disc_gradients, discriminator.trainable_variables))
        
        return gen_loss, disc_loss

    generated_samples = []
    
    # Training loop
    for epoch in range(epochs):
        idx = np.random.randint(0, train_data.shape[0], batch_size)
        real_batch = train_data[idx]
        
        g_loss, d_loss = train_step(real_batch)
        
        if epoch % 10 == 0:
            print(f"Epoch {epoch}, G Loss: {g_loss:.4f}, D Loss: {d_loss:.4f}")
    
    # Generate samples until we reach target number
    remaining_samples = target_samples
    batch_size = 32  # Larger batch size for generation
    
    while remaining_samples > 0:
        current_batch = min(batch_size, remaining_samples)
        noise = tf.random.normal([current_batch, 100])
        generated = generator(noise, training=False)
        generated_samples.append(generated.numpy())
        remaining_samples -= current_batch
        
        # Print progress
        print(f"Generated {len(generated_samples) * batch_size} samples out of {target_samples}")
    
    return np.concatenate(generated_samples)[:target_samples]

# Fungsi visualisasi
def plot_comparison(real_data, fake_data, title):
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(real_data[0].reshape(-1))
    plt.title(f'Data Asli {title}')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    
    plt.subplot(1, 2, 2)
    plt.plot(fake_data[0].reshape(-1))
    plt.title(f'Data Palsu {title}')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    
    plt.tight_layout()
    plt.show()

# Build models
generator = build_generator()
discriminator = build_discriminator()

# Training PMI
print("Training GAN untuk PMI data:")
pmi_fake = train_gan(generator, discriminator, pmi_train_processed, target_samples=3000)

# Training LMI
print("\nTraining GAN untuk LMI data:")
lmi_fake = train_gan(generator, discriminator, lmi_train_processed, target_samples=3000)

# Visualisasi hasil
plot_comparison(pmi_train_processed, pmi_fake, "PMI")
plot_comparison(lmi_train_processed, lmi_fake, "LMI")

# Informasi jumlah data
print("\nInformasi jumlah data:")
print(f"PMI asli - Training: {len(pmi_train_processed)}, Testing: {len(pmi_test_processed)}")
print(f"PMI palsu: {len(pmi_fake)}")
print(f"LMI asli - Training: {len(lmi_train_processed)}, Testing: {len(lmi_test_processed)}")
print(f"LMI palsu: {len(lmi_fake)}")

# Save generated data (optional)
np.save('pmi_fake_data.npy', pmi_fake)
np.save('lmi_fake_data.npy', lmi_fake)
# Out:
# Shape PMI train: (168, 1000, 1)
# Shape LMI train: (1932, 1000, 1)
# Training GAN untuk PMI data:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 0, G Loss: 0.7303, D Loss: 1.3461
# Epoch 10, G Loss: 0.7334, D Loss: 1.3487
# Epoch 20, G Loss: 0.7202, D Loss: 1.3383
# Epoch 30, G Loss: 0.6823, D Loss: 1.3463
# Epoch 40, G Loss: 0.7089, D Loss: 1.2567
# Epoch 50, G Loss: 0.6642, D Loss: 1.2446
# Epoch 60, G Loss: 0.7490, D Loss: 1.2007
# Epoch 70, G Loss: 0.7689, D Loss: 1.2890
# Epoch 80, G Loss: 0.7850, D Loss: 1.2763
# Epoch 90, G Loss: 0.8063, D Loss: 1.3087
# Epoch 100, G Loss: 0.7138, D Loss: 1.3778
# Epoch 110, G Loss: 0.9048, D Loss: 1.0169
# Epoch 120, G Loss: 0.7357, D Loss: 1.3096
# Epoch 130, G Loss: 0.6510, D Loss: 1.3022
# Generated 1024 samples out of 3000
# Generated 1056 samples out of 3000
# Generated 1088 samples out of 3000
# Generated 1120 samples out of 3000
# Generated 1152 samples out of 3000
# Generated 1184 samples out of 3000
# Generated 1216 samples out of 3000
# Generated 1248 samples out of 3000
# Generated 1280 samples out of 3000
# Generated 1312 samples out of 3000
# Generated 1344 samples out of 3000
# Generated 1376 samples out of 3000
# Generated 1408 samples out of 3000
# Generated 1440 samples out of 3000
# Generated 1472 samples out of 3000
# Generated 1504 samples out of 3000
# Generated 1536 samples out of 3000
# Generated 1568 samples out of 3000
# Generated 1600 samples out of 3000
# Generated 1632 samples out of 3000
# Generated 1664 samples out of 3000
# Generated 1696 samples out of 3000
# Generated 1728 samples out of 3000
# Generated 1760 samples out of 3000
# Generated 1792 samples out of 3000
# Generated 1824 samples out of 3000
# Generated 1856 samples out of 3000
# Generated 1888 samples out of 3000
# Generated 1920 samples out of 3000
# Generated 1952 samples out of 3000
# Generated 1984 samples out of 3000
# Generated 2016 samples out of 3000
# Generated 2048 samples out of 3000
# Generated 2080 samples out of 3000
# Generated 2112 samples out of 3000
# Generated 2144 samples out of 3000
# Generated 2176 samples out of 3000
# Generated 2208 samples out of 3000
# Generated 2240 samples out of 3000
# Generated 2272 samples out of 3000
# Generated 2304 samples out of 3000
# Generated 2336 samples out of 3000
# Generated 2368 samples out of 3000
# Generated 2400 samples out of 3000
# Generated 2432 samples out of 3000
# Generated 2464 samples out of 3000
# Generated 2496 samples out of 3000
# Generated 2528 samples out of 3000
# Generated 2560 samples out of 3000
# Generated 2592 samples out of 3000
# Generated 2624 samples out of 3000
# Generated 2656 samples out of 3000
# Generated 2688 samples out of 3000
# Generated 2720 samples out of 3000
# Generated 2752 samples out of 3000
# Generated 2784 samples out of 3000
# Generated 2816 samples out of 3000
# Generated 2848 samples out of 3000
# Generated 2880 samples out of 3000
# Generated 2912 samples out of 3000
# Generated 2944 samples out of 3000
# Generated 2976 samples out of 3000
# Generated 3008 samples out of 3000
# Informasi jumlah data:
# PMI asli - Training: 168, Testing: 36
# PMI palsu: 3000
# LMI asli - Training: 1932, Testing: 480
# LMI palsu: 3000

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Function to prepare labels for the data
def prepare_labels(data_dict):
    labels = []
    combined_data = []
    
    for label, data in data_dict.items():
        n_samples = len(data)
        labels.extend([label] * n_samples)
        combined_data.append(data)
    
    return np.concatenate(combined_data), np.array(labels)

# Let's first check the shapes of our data
print("Original shapes:")
print("LMI fake shape:", lmi_fake.shape)
print("PMI fake shape:", pmi_fake.shape)
print("Real ECG data shape:", ECG_data.shape)

# Reshape GAN-generated data to match real data dimensions
# We'll duplicate the single channel 12 times
def reshape_gan_data(gan_data):
    # First reshape back to (n_samples, timesteps)
    n_samples = gan_data.shape[0]
    timesteps = 1000  # Based on your original data
    reshaped = gan_data.reshape(n_samples, timesteps)
    
    # Create 12 copies of the channel
    multi_channel = np.stack([reshaped] * 12, axis=-1)
    return multi_channel

# Reshape GAN data
lmi_fake_reshaped = reshape_gan_data(lmi_fake)
pmi_fake_reshaped = reshape_gan_data(pmi_fake)

print("\nAfter reshaping:")
print("LMI fake reshaped shape:", lmi_fake_reshaped.shape)
print("PMI fake reshaped shape:", pmi_fake_reshaped.shape)

# Prepare real data dictionary
real_data = {
    'NORM': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'NORM' in x)],
    'AMI': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'AMI' in x)],
    'IMI': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'IMI' in x)],
    'LMI': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'LMI' in x)],
    'PMI': ECG_data[filtered_ECG_df['scp_subclasses'].apply(lambda x: 'PMI' in x)]
}

# Add GAN-generated data
real_data['LMI'] = np.concatenate([real_data['LMI'], lmi_fake_reshaped])
real_data['PMI'] = np.concatenate([real_data['PMI'], pmi_fake_reshaped])

# Prepare the combined dataset
X, y = prepare_labels(real_data)

# Preprocess the data
# Normalize each channel independently
X_processed = np.zeros_like(X, dtype=np.float32)
for i in range(12):
    X_processed[:, :, i] = (X[:, :, i] - np.mean(X[:, :, i])) / np.std(X[:, :, i])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# Print information about the dataset
print("\nDataset Information:")
print("===================")
print(f"Total number of samples: {len(X)}")
print("Input shape:", X.shape)

print("\nClass distribution in complete dataset:")
for label in np.unique(y):
    count = np.sum(y == label)
    percentage = (count / len(y)) * 100
    print(f"{label}: {count} samples ({percentage:.2f}%)")

print("\nTraining set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)

print("\nClass distribution in training set:")
for label in np.unique(y_train):
    count = np.sum(y_train == label)
    percentage = (count / len(y_train)) * 100
    print(f"{label}: {count} samples ({percentage:.2f}%)")

print("\nClass distribution in testing set:")
for label in np.unique(y_test):
    count = np.sum(y_test == label)
    percentage = (count / len(y_test)) * 100
    print(f"{label}: {count} samples ({percentage:.2f}%)")

# Save the processed datasets (optional)
np.save('X_train.npy', X_train)
np.save('X_test.npy', X_test)
np.save('y_train.npy', y_train)
np.save('y_test.npy', y_test)
# Out:
# Original shapes:
# LMI fake shape: (3000, 1000, 1)
# PMI fake shape: (3000, 1000, 1)
# Real ECG data shape: (14982, 1000, 12)
#
# After reshaping:
# LMI fake reshaped shape: (3000, 1000, 12)
# PMI fake reshaped shape: (3000, 1000, 12)
#
# Dataset Information:
# ===================
# Total number of samples: 22081
# Input shape: (22081, 1000, 12)
#
# Class distribution in complete dataset:
# AMI: 3078 samples (13.94%)
# IMI: 3271 samples (14.81%)
# LMI: 3201 samples (14.50%)
# NORM: 9514 samples (43.09%)
# PMI: 3017 samples (13.66%)
#
# Training set shape: (17664, 1000, 12)
# Testing set shape: (4417, 1000, 12)
#
# Class distribution in training set:
# AMI: 2462 samples (13.94%)
# IMI: 2617 samples (14.82%)
# LMI: 2561 samples (14.50%)
# NORM: 7611 samples (43.09%)
# PMI: 2413 samples (13.66%)
#
# Class distribution in testing set:
# AMI: 616 samples (13.95%)
# IMI: 654 samples (14.81%)
# LMI: 640 samples (14.49%)
# NORM: 1903 samples (43.08%)
# PMI: 604 samples (13.67%)

# %% [markdown]
# ## Hasil GAN

# %%
# Menghitung jumlah data untuk setiap subclass (data asli)
def count_original_data(filtered_df, subclasses):
    counts = {}
    for subclass in subclasses:
        count = len(filtered_df[filtered_df['scp_subclasses'].apply(lambda x: subclass in x)])
        counts[subclass] = count
    return counts

# Hitung jumlah data asli
original_counts = count_original_data(filtered_ECG_df, selected_subclasses)

# Hitung jumlah data setelah GAN
# Asumsikan kita memiliki data palsu untuk PMI dan LMI
gan_counts = original_counts.copy()
gan_counts['PMI'] += len(pmi_fake)  # Tambahkan jumlah data PMI palsu
gan_counts['LMI'] += len(lmi_fake)  # Tambahkan jumlah data LMI palsu

# Membuat subplot untuk membandingkan distribusi sebelum dan sesudah GAN
plt.figure(figsize=(20, 8))

# Pie chart untuk data asli
plt.subplot(1, 2, 1)
plt.pie(original_counts.values(), 
        labels=original_counts.keys(),
        autopct='%1.1f%%',
        startangle=90)
plt.title('Distribusi Data ECG Original')

# Pie chart untuk data setelah GAN
plt.subplot(1, 2, 2)
plt.pie(gan_counts.values(), 
        labels=gan_counts.keys(),
        autopct='%1.1f%%',
        startangle=90)
plt.title('Distribusi Data ECG Setelah GAN')

plt.tight_layout()
plt.show()

# Menampilkan jumlah data dalam bentuk tabel
print("\nJumlah data untuk setiap subclass:")
print("\nData Original:")
for subclass, count in original_counts.items():
    print(f"{subclass}: {count} data")

print("\nData Setelah GAN:")
for subclass, count in gan_counts.items():
    print(f"{subclass}: {count} data")

print("\nJumlah data yang ditambahkan oleh GAN:")
print(f"PMI: {len(pmi_fake)} data")
print(f"LMI: {len(lmi_fake)} data")

# Menghitung persentase peningkatan
pmi_increase = (gan_counts['PMI'] - original_counts['PMI']) / original_counts['PMI'] * 100
lmi_increase = (gan_counts['LMI'] - original_counts['LMI']) / original_counts['LMI'] * 100

print(f"\nPersentase peningkatan data:")
print(f"PMI: {pmi_increase:.1f}%")
print(f"LMI: {lmi_increase:.1f}%")
# Out:
# Jumlah data untuk setiap subclass:
#
# Data Original:
# NORM: 9514 data
# PMI: 17 data
# LMI: 201 data
# AMI: 3078 data
# IMI: 3271 data
#
# Data Setelah GAN:
# NORM: 9514 data
# PMI: 3017 data
# LMI: 3201 data
# AMI: 3078 data
# IMI: 3271 data
#
# Jumlah data yang ditambahkan oleh GAN:
# PMI: 3000 data
# LMI: 3000 data
#
# Persentase peningkatan data:
# PMI: 17647.1%
# LMI: 1492.5%

# %%
# Menggabungkan data asli dan data palsu untuk training
def combine_data_for_training(real_train, fake_data):
    # Menggabungkan data training asli dengan data palsu
    combined_train = np.concatenate([real_train, fake_data])
    return combined_train

# Fungsi untuk membuat dataset final
def prepare_final_dataset():
    # Data Training = Data training asli + Data GAN
    pmi_combined_train = combine_data_for_training(pmi_train_processed, pmi_fake)
    lmi_combined_train = combine_data_for_training(lmi_train_processed, lmi_fake)
    
    # Data Testing = Hanya data testing asli
    pmi_final_test = pmi_test_processed
    lmi_final_test = lmi_test_processed
    
    # Print informasi dataset
    print("\nInformasi Dataset Final:")
    print("\nPMI:")
    print(f"Training (asli + palsu): {len(pmi_combined_train)} sampel")
    print(f"- Data asli: {len(pmi_train_processed)} sampel")
    print(f"- Data palsu: {len(pmi_fake)} sampel")
    print(f"Testing (hanya asli): {len(pmi_final_test)} sampel")
    
    print("\nLMI:")
    print(f"Training (asli + palsu): {len(lmi_combined_train)} sampel")
    print(f"- Data asli: {len(lmi_train_processed)} sampel")
    print(f"- Data palsu: {len(lmi_fake)} sampel")
    print(f"Testing (hanya asli): {len(lmi_final_test)} sampel")
    
    return {
        'pmi_train': pmi_combined_train,
        'pmi_test': pmi_final_test,
        'lmi_train': lmi_combined_train,
        'lmi_test': lmi_final_test
    }

# Membuat dataset final
final_dataset = prepare_final_dataset()

# Optional: Simpan dataset
np.save('pmi_train_final.npy', final_dataset['pmi_train'])
np.save('pmi_test_final.npy', final_dataset['pmi_test'])
np.save('lmi_train_final.npy', final_dataset['lmi_train'])
np.save('lmi_test_final.npy', final_dataset['lmi_test'])

# Visualisasi distribusi data
def plot_data_distribution():
    labels = ['PMI', 'LMI']
    train_real = [len(pmi_train_processed), len(lmi_train_processed)]
    train_fake = [len(pmi_fake), len(lmi_fake)]
    test_data = [len(final_dataset['pmi_test']), len(final_dataset['lmi_test'])]
    
    x = np.arange(len(labels))
    width = 0.25
    
    fig, ax = plt.subplots(figsize=(10, 6))
    rects1 = ax.bar(x - width, train_real, width, label='Training (Asli)')
    rects2 = ax.bar(x, train_fake, width, label='Training (GAN)')
    rects3 = ax.bar(x + width, test_data, width, label='Testing (Asli)')
    
    ax.set_ylabel('Jumlah Sampel')
    ax.set_title('Distribusi Data')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()
    
    plt.tight_layout()
    plt.show()

# Tampilkan visualisasi
plot_data_distribution()
# Out:
# Informasi Dataset Final:
#
# PMI:
# Training (asli + palsu): 3168 sampel
# - Data asli: 168 sampel
# - Data palsu: 3000 sampel
# Testing (hanya asli): 36 sampel
#
# LMI:
# Training (asli + palsu): 4932 sampel
# - Data asli: 1932 sampel
# - Data palsu: 3000 sampel
# Testing (hanya asli): 480 sampel

# %%
print("Shape data:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Shape data:
# X_train shape: (17664, 1000, 12)
# y_train shape: (17664,)
# X_test shape: (4417, 1000, 12)
# y_test shape: (4417,)

# %% [markdown]
# # MODEL

# %% [markdown]
# ## LSTM model

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import os

# Buat folder untuk menyimpan hasil setiap fold
if not os.path.exists('fold_results'):
    os.makedirs('fold_results')

# Encode labels (sama seperti sebelumnya)
le = LabelEncoder()
y_encoded = le.fit_transform(y_train)
y_train_cat = to_categorical(y_encoded)

y_test_encoded = le.transform(y_test)
y_test_cat = to_categorical(y_test_encoded)

def build_lstm_model(input_shape, num_classes=5):
    model = Sequential([
        LSTM(100, return_sequences=False, input_shape=input_shape),
        Dropout(0.2),
        Dense(num_classes, activation='softmax')
    ])
    
    optimizer = Adam(learning_rate=0.0001)
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

def get_callbacks(fold):
    fold_dir = f'fold_results/fold_{fold}'
    if not os.path.exists(fold_dir):
        os.makedirs(fold_dir)
        
    return [
        ModelCheckpoint(
            f'{fold_dir}/best_lstm_model_5class.keras',
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1,
            mode='max'
        ),
        EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=0.00001,
            verbose=1
        )
    ]

def plot_training_history(history, fold, save_dir):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    # Plot accuracy
    ax1.plot(history.history['accuracy'])
    ax1.plot(history.history['val_accuracy'])
    ax1.set_title(f'Model Accuracy - Fold {fold}')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['Train', 'Validation'])
    
    # Plot loss
    ax2.plot(history.history['loss'])
    ax2.plot(history.history['val_loss'])
    ax2.set_title(f'Model Loss - Fold {fold}')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend(['Train', 'Validation'])
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/training_history.png')
    plt.close()

def evaluate_model(model, X_test, y_test, class_names, fold, save_dir):
    # Prediksi
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)
    
    # Metrics
    accuracy = accuracy_score(y_test_classes, y_pred_classes)
    precision = precision_score(y_test_classes, y_pred_classes, average='weighted')
    recall = recall_score(y_test_classes, y_pred_classes, average='weighted')
    f1 = f1_score(y_test_classes, y_pred_classes, average='weighted')
    
    # Save metrics to file
    with open(f'{save_dir}/evaluation_metrics.txt', 'w', encoding='utf-8') as f:
        f.write(f"Fold {fold} Evaluation Metrics:\n")
        f.write(f"Accuracy: {accuracy:.4f}\n")
        f.write(f"Precision: {precision:.4f}\n")
        f.write(f"Recall: {recall:.4f}\n")
        f.write(f"F1-Score: {f1:.4f}\n")
    
    # Confusion Matrix
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title(f'Confusion Matrix - Fold {fold}')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.savefig(f'{save_dir}/confusion_matrix.png')
    plt.close()
    
    # Save confusion matrix as CSV
    cm_df = pd.DataFrame(cm, 
                        index=class_names,
                        columns=class_names)
    cm_df.to_csv(f'{save_dir}/confusion_matrix.csv')
    
    # Per-class metrics
    per_class_metrics = []
    for i, class_name in enumerate(class_names):
        class_precision = precision_score(y_test_classes, y_pred_classes, average=None)[i]
        class_recall = recall_score(y_test_classes, y_pred_classes, average=None)[i]
        class_f1 = f1_score(y_test_classes, y_pred_classes, average=None)[i]
        
        tp = cm[i, i]
        fp = np.sum(cm[:, i]) - tp
        fn = np.sum(cm[i, :]) - tp
        tn = np.sum(cm) - tp - fp - fn
        specificity = tn/(tn+fp)
        
        per_class_metrics.append({
            'Class': class_name,
            'True Positives': tp,
            'True Negatives': tn,
            'False Positives': fp,
            'False Negatives': fn,
            'Precision': class_precision,
            'Recall': class_recall,
            'F1-Score': class_f1,
            'Specificity': specificity
        })
    
    # Save per-class metrics
    with open(f'{save_dir}/per_class_metrics.txt', 'w', encoding='utf-8') as f:
        for metrics in per_class_metrics:
            f.write(f"\n{metrics['Class']}:\n")
            f.write(f"True Positives (TP): {metrics['True Positives']}\n")
            f.write(f"True Negatives (TN): {metrics['True Negatives']}\n")
            f.write(f"False Positives (FP): {metrics['False Positives']}\n")
            f.write(f"False Negatives (FN): {metrics['False Negatives']}\n")
            f.write(f"Precision: {metrics['Precision']:.4f}\n")
            f.write(f"Recall: {metrics['Recall']:.4f}\n")
            f.write(f"F1-Score: {metrics['F1-Score']:.4f}\n")
            f.write(f"Specificity: {metrics['Specificity']:.4f}\n")
    
    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'confusion_matrix': cm,
        'confusion_matrix_df': cm_df,
        'per_class_metrics': per_class_metrics
    }

# Inisialisasi K-Fold
n_folds = 5
kfold = KFold(n_splits=n_folds, shuffle=True, random_state=42)

# List untuk menyimpan hasil setiap fold
fold_histories = []
fold_results = []

# K-Fold Cross Validation
for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train)):
    fold_num = fold + 1
    print(f'\nFold {fold_num}/{n_folds}')
    fold_dir = f'fold_results/fold_{fold_num}'
    
    # Split data untuk fold ini
    X_train_fold = X_train[train_idx]
    y_train_fold = y_train_cat[train_idx]
    X_val_fold = X_train[val_idx]
    y_val_fold = y_train_cat[val_idx]
    
    # Build model
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_lstm_model(input_shape)
    
    if fold == 0:
        model.summary()
        # Save model summary to file
        with open('model_summary.txt', 'w', encoding='utf-8') as f:
            from io import StringIO
            summary_string = StringIO()
            model.summary(print_fn=lambda x: summary_string.write(x + '\n'))
            f.write(summary_string.getvalue())
    
    # Training
    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        epochs=50,
        batch_size=8,
        callbacks=get_callbacks(fold_num),
        verbose=1
    )
    
    # Save training history
    pd.DataFrame(history.history).to_csv(f'{fold_dir}/training_history.csv', index=False)
    plot_training_history(history, fold_num, fold_dir)
    
    # Evaluasi pada validation fold
    fold_results.append(
        evaluate_model(model, X_val_fold, y_val_fold, le.classes_, fold_num, fold_dir)
    )
    fold_histories.append(history.history)

# Menghitung dan menyimpan rata-rata metrics dari semua fold
avg_metrics = {
    'accuracy': np.mean([res['accuracy'] for res in fold_results]),
    'precision': np.mean([res['precision'] for res in fold_results]),
    'recall': np.mean([res['recall'] for res in fold_results]),
    'f1': np.mean([res['f1'] for res in fold_results])
}

# Simpan hasil K-Fold
kfold_results_df = pd.DataFrame({
    'Fold': range(1, n_folds + 1),
    'Accuracy': [res['accuracy'] for res in fold_results],
    'Precision': [res['precision'] for res in fold_results],
    'Recall': [res['recall'] for res in fold_results],
    'F1-Score': [res['f1'] for res in fold_results]
})
kfold_results_df.loc[len(kfold_results_df)] = ['Average', 
                                              avg_metrics['accuracy'], 
                                              avg_metrics['precision'], 
                                              avg_metrics['recall'],
                                              avg_metrics['f1']]
kfold_results_df.to_csv('fold_results/kfold_results_summary.csv', index=False)

# Plot hasil K-Fold
plt.figure(figsize=(12, 6))
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
for metric in metrics:
    plt.plot(range(1, n_folds + 1), kfold_results_df[metric][:n_folds], 
             marker='o', label=metric)
plt.title('Model Metrics Across Folds')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.savefig('fold_results/kfold_metrics_comparison.png')
plt.close()

# Final model training dan evaluasi
print("\nTraining final model on complete training set...")
final_model = build_lstm_model(input_shape)
final_history = final_model.fit(
    X_train, y_train_cat,
    validation_split=0.2,
    epochs=50,
    batch_size=8,
    callbacks=get_callbacks('final'),
    verbose=1
)

# Save final model results
final_dir = 'fold_results/final_model'
if not os.path.exists(final_dir):
    os.makedirs(final_dir)

# Plot dan save training history untuk model final
plot_training_history(final_history, 'Final', final_dir)
pd.DataFrame(final_history.history).to_csv(f'{final_dir}/training_history.csv', index=False)

# Evaluasi model final pada test set
final_results = evaluate_model(final_model, X_test, y_test_cat, le.classes_, 'Final', final_dir)

# Save final model
final_model.save(f'{final_dir}/final_lstm_model_5class.h5')
# Out:
# Fold 1/5
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 100)            │        45,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           505 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,705 (178.54 KB)
#  Trainable params: 45,705 (178.54 KB)
#  Non-trainable params: 0 (0.00 B)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5010 - loss: 1.1909
# Epoch 1: val_accuracy improved from -inf to 0.62213, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 213s 120ms/step - accuracy: 0.5010 - loss: 1.1908 - val_accuracy: 0.6221 - val_loss: 0.8808 - learning_rate: 1.0000e-04
# Epoch 2/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6513 - loss: 0.8573
# Epoch 2: val_accuracy did not improve from 0.62213
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 211s 119ms/step - accuracy: 0.6513 - loss: 0.8573 - val_accuracy: 0.5856 - val_loss: 0.9744 - learning_rate: 1.0000e-04
# Epoch 3/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.
- learning_rate: 1.0000e-04
# Epoch 21/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.7990 - loss: 0.5227
# Epoch 21: val_accuracy improved from 0.80243 to 0.80923, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.7990 - loss: 0.5227 - val_accuracy: 0.8092 - val_loss: 0.4922 - learning_rate: 1.0000e-04
# Epoch 22/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8089 - loss: 0.5036
# Epoch 22: val_accuracy did not improve from 0.80923
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8089 - loss: 0.5036 - val_accuracy: 0.7855 - val_loss: 0.6672 - learning_rate: 1.0000e-04
# Epoch 23/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8064 - loss: 0.5132
# Epoch 23: val_accuracy improved from 0.80923 to 0.82083, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.8065 - loss: 0.5132 - val_accuracy: 0.8208 - val_loss: 0.4650 - learning_rate: 1.0000e-04
# Epoch 24/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8141 - loss: 0.4930
# Epoch 24: val_accuracy did not improve from 0.82083
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.8141 - loss: 0.4930 - val_accuracy: 0.8101 - val_loss: 0.4759 - learning_rate: 1.0000e-04
# Epoch 25/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7697 - loss: 0.6229
# Epoch 25: val_accuracy did not improve from 0.82083
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 228s 129ms/step - accuracy: 0.7697 - loss: 0.6228 - val_accuracy: 0.8205 - val_loss: 0.4661 - learning_rate: 1.0000e-04
# Epoch 26/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8139 - loss: 0.4921
# Epoch 26: val_accuracy did not improve from 0.82083
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8139 - loss: 0.4921 - val_accuracy: 0.8163 - val_loss: 0.4854 - learning_rate: 1.0000e-04
# Epoch 27/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8172 - loss: 0.4945
# Epoch 27: val_accuracy did not improve from 0.82083
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8172 - loss: 0.4945 - val_accuracy: 0.8169 - val_loss: 0.5059 - learning_rate: 1.0000e-04
# Epoch 28/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8001 - loss: 0.5509
# Epoch 28: val_accuracy did not improve from 0.82083
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8001 - loss: 0.5509 - val_accuracy: 0.8027 - val_loss: 0.5133 - learning_rate: 1.0000e-04
# Epoch 29/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8202 - loss: 0.4905
# Epoch 29: val_accuracy improved from 0.82083 to 0.82479, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8202 - loss: 0.4905 - val_accuracy: 0.8248 - val_loss: 0.4575 - learning_rate: 5.0000e-05
# Epoch 30/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8303 - loss: 0.4585
# Epoch 30: val_accuracy improved from 0.82479 to 0.82621, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.8303 - loss: 0.4585 - val_accuracy: 0.8262 - val_loss: 0.4659 - learning_rate: 5.0000e-05
# Epoch 31/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8293 - loss: 0.4530
# Epoch 31: val_accuracy did not improve from 0.82621
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.8293 - loss: 0.4530 - val_accuracy: 0.8242 - val_loss: 0.4566 - learning_rate: 5.0000e-05
# Epoch 32/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8330 - loss: 0.4359
# Epoch 32: val_accuracy did not improve from 0.82621
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 221s 125ms/step - accuracy: 0.8330 - loss: 0.4359 - val_accuracy: 0.8239 - val_loss: 0.4494 - learning_rate: 5.0000e-05
# Epoch 33/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8368 - loss: 0.4353
# Epoch 33: val_accuracy did not improve from 0.82621
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.8368 - loss: 0.4353 - val_accuracy: 0.8217 - val_loss: 0.4500 - learning_rate: 5.0000e-05
# Epoch 34/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8326 - loss: 0.4303
# Epoch 34: val_accuracy did not improve from 0.82621
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.8326 - loss: 0.4303 - val_accuracy: 0.8239 - val_loss: 0.4413 - learning_rate: 5.0000e-05
# Epoch 35/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8432 - loss: 0.4245
# Epoch 35: val_accuracy did not improve from 0.82621
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8432 - loss: 0.4245 - val_accuracy: 0.8256 - val_loss: 0.4434 - learning_rate: 5.0000e-05
# Epoch 36/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8430 - loss: 0.4247
# Epoch 36: val_accuracy improved from 0.82621 to 0.83159, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.8430 - loss: 0.4247 - val_accuracy: 0.8316 - val_loss: 0.4447 - learning_rate: 5.0000e-05
# Epoch 37/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8362 - loss: 0.4289
# Epoch 37: val_accuracy did not improve from 0.83159
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8362 - loss: 0.4289 - val_accuracy: 0.8265 - val_loss: 0.4497 - learning_rate: 5.0000e-05
# Epoch 38/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8434 - loss: 0.4144
# Epoch 38: val_accuracy did not improve from 0.83159
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8434 - loss: 0.4144 - val_accuracy: 0.8013 - val_loss: 0.5178 - learning_rate: 5.0000e-05
# Epoch 39/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8237 - loss: 0.4545
# Epoch 39: val_accuracy did not improve from 0.83159
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8237 - loss: 0.4545 - val_accuracy: 0.8293 - val_loss: 0.4394 - learning_rate: 5.0000e-05
# Epoch 40/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8392 - loss: 0.4205
# Epoch 40: val_accuracy did not improve from 0.83159
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8392 - loss: 0.4205 - val_accuracy: 0.8268 - val_loss: 0.4413 - learning_rate: 5.0000e-05
# Epoch 41/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8404 - loss: 0.4231
# Epoch 41: val_accuracy improved from 0.83159 to 0.83300, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8404 - loss: 0.4230 - val_accuracy: 0.8330 - val_loss: 0.4306 - learning_rate: 5.0000e-05
# Epoch 42/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8532 - loss: 0.3890
# Epoch 42: val_accuracy did not improve from 0.83300
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.8532 - loss: 0.3890 - val_accuracy: 0.8324 - val_loss: 0.4311 - learning_rate: 5.0000e-05
# Epoch 43/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8487 - loss: 0.4037
# Epoch 43: val_accuracy improved from 0.83300 to 0.83527, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8487 - loss: 0.4037 - val_accuracy: 0.8353 - val_loss: 0.4277 - learning_rate: 5.0000e-05
# Epoch 44/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8488 - loss: 0.4001
# Epoch 44: val_accuracy did not improve from 0.83527
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 126ms/step - accuracy: 0.8488 - loss: 0.4001 - val_accuracy: 0.8316 - val_loss: 0.4318 - learning_rate: 5.0000e-05
# Epoch 45/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8508 - loss: 0.3918
# Epoch 45: val_accuracy improved from 0.83527 to 0.84234, saving model to fold_results/fold_1/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8508 - loss: 0.3919 - val_accuracy: 0.8423 - val_loss: 0.4215 - learning_rate: 5.0000e-05
# Epoch 46/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8511 - loss: 0.3971
# Epoch 46: val_accuracy did not improve from 0.84234
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8511 - loss: 0.3971 - val_accuracy: 0.8421 - val_loss: 0.4238 - learning_rate: 5.0000e-05
# Epoch 47/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8532 - loss: 0.3905
# Epoch 47: val_accuracy did not improve from 0.84234
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 228s 129ms/step - accuracy: 0.8532 - loss: 0.3905 - val_accuracy: 0.8339 - val_loss: 0.4435 - learning_rate: 5.0000e-05
# Epoch 48/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8552 - loss: 0.3919
# Epoch 48: val_accuracy did not improve from 0.84234
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 227s 129ms/step - accuracy: 0.8552 - loss: 0.3919 - val_accuracy: 0.8404 - val_loss: 0.4156 - learning_rate: 5.0000e-05
# Epoch 49/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8588 - loss: 0.3890
# Epoch 49: val_accuracy did not improve from 0.84234
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 226s 128ms/step - accuracy: 0.8165 - loss: 0.4924 - val_accuracy: 0.8143 - val_loss: 0.4620 - learning_rate: 1.0000e-04
# Epoch 29/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8366 - loss: 0.4374
# Epoch 29: val_accuracy did not improve from 0.81800
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 227s 128ms/step - accuracy: 0.8366 - loss: 0.4374 - val_accuracy: 0.8104 - val_loss: 0.4789 - learning_rate: 1.0000e-04
# Epoch 30/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8133 - loss: 0.4493
# Epoch 30: val_accuracy did not improve from 0.81800
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 227s 129ms/step - accuracy: 0.8133 - loss: 0.4493 - val_accuracy: 0.8169 - val_loss: 0.4599 - learning_rate: 1.0000e-04
# Epoch 31/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8264 - loss: 0.4380
# Epoch 31: val_accuracy improved from 0.81800 to 0.82112, saving model to fold_results/fold_2/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 227s 128ms/step - accuracy: 0.8264 - loss: 0.4380 - val_accuracy: 0.8211 - val_loss: 0.4552 - learning_rate: 1.0000e-04
# Epoch 32/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8393 - loss: 0.4255
# Epoch 32: val_accuracy improved from 0.82112 to 0.82876, saving model to fold_results/fold_2/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 226s 128ms/step - accuracy: 0.8393 - loss: 0.4256 - val_accuracy: 0.8288 - val_loss: 0.4373 - learning_rate: 1.0000e-04
# Epoch 33/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8443 - loss: 0.4083
# Epoch 33: val_accuracy improved from 0.82876 to 0.82932, saving model to fold_results/fold_2/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 227s 128ms/step - accuracy: 0.8443 - loss: 0.4083 - val_accuracy: 0.8293 - val_loss: 0.4289 - learning_rate: 1.0000e-04
# Epoch 34/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8427 - loss: 0.4110
# Epoch 34: val_accuracy did not improve from 0.82932
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 257s 145ms/step - accuracy: 0.8427 - loss: 0.4110 - val_accuracy: 0.8262 - val_loss: 0.4478 - learning_rate: 1.0000e-04
# Epoch 35/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8419 - loss: 0.4153
# Epoch 35: val_accuracy improved from 0.82932 to 0.83017, saving model to fold_results/fold_2/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 264s 149ms/step - accuracy: 0.8419 - loss: 0.4153 - val_accuracy: 0.8302 - val_loss: 0.4332 - learning_rate: 1.0000e-04
# Epoch 36/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8385 - loss: 0.4095
# Epoch 36: val_accuracy did not improve from 0.83017
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 263s 149ms/step - accuracy: 0.8385 - loss: 0.4095 - val_accuracy: 0.6915 - val_loss: 0.6993 - learning_rate: 1.0000e-04
# Epoch 37/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8319 - loss: 0.4275
# Epoch 37: val_accuracy improved from 0.83017 to 0.83697, saving model to fold_results/fold_2/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 243s 137ms/step - accuracy: 0.8319 - loss: 0.4275 - val_accuracy: 0.8370 - val_loss: 0.4395 - learning_rate: 1.0000e-04
# Epoch 38/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8476 - loss: 0.4022
# Epoch 38: val_accuracy did not improve from 0.83697
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 230s 130ms/step - accuracy: 0.8476 - loss: 0.4022 - val_accuracy: 0.8279 - val_loss: 0.4623 - learning_rate: 1.0000e-04
# Epoch 39/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8319 - loss: 0.4331
# Epoch 39: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 229s 130ms/step - accuracy: 0.8319 - loss: 0.4331 - val_accuracy: 0.8239 - val_loss: 0.4530 - learning_rate: 5.0000e-05
# Epoch 40/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8416 - loss: 0.4045
# Epoch 40: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 229s 130ms/step - accuracy: 0.8416 - loss: 0.4045 - val_accuracy: 0.8344 - val_loss: 0.4322 - learning_rate: 5.0000e-05
# Epoch 41/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8509 - loss: 0.3948
# Epoch 41: val_accuracy improved from 0.83697 to 0.84149, saving model to fold_results/fold_2/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 240s 136ms/step - accuracy: 0.8509 - loss: 0.3948 - val_accuracy: 0.8415 - val_loss: 0.4258 - learning_rate: 5.0000e-05
# Epoch 42/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8590 - loss: 0.3768
# Epoch 42: val_accuracy did not improve from 0.84149
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 227s 128ms/step - accuracy: 0.8590 - loss: 0.3769 - val_accuracy: 0.8330 - val_loss: 0.4328 - learning_rate: 5.0000e-05
# Epoch 43/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8518 - loss: 0.3791
# Epoch 43: val_accuracy did not improve from 0.84149
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 226s 128ms/step - accuracy: 0.8518 - loss: 0.3791 - val_accuracy: 0.8347 - val_loss: 0.4383 - learning_rate: 5.0000e-05
# Epoch 44/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8562 - loss: 0.3853
# Epoch 44: val_accuracy improved from 0.84149 to 0.84546, saving model to fold_results/fold_2/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 225s 127ms/step - accuracy: 0.8562 - loss: 0.3853 - val_accuracy: 0.8455 - val_loss: 0.4104 - learning_rate: 5.0000e-05
# Epoch 45/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8583 - loss: 0.3700
# Epoch 45: val_accuracy improved from 0.84546 to 0.84574, saving model to fold_results/fold_2/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8583 - loss: 0.3700 - val_accuracy: 0.8457 - val_loss: 0.4109 - learning_rate: 5.0000e-05
# Epoch 46/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8588 - loss: 0.3848
# Epoch 46: val_accuracy did not improve from 0.84574
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8588 - loss: 0.3848 - val_accuracy: 0.8432 - val_loss: 0.4090 - learning_rate: 5.0000e-05
# Epoch 47/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8602 - loss: 0.4086
# Epoch 47: val_accuracy did not improve from 0.84574
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8602 - loss: 0.4085 - val_accuracy: 0.8412 - val_loss: 0.4092 - learning_rate: 5.0000e-05
# Epoch 48/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8583 - loss: 0.3720
# Epoch 48: val_accuracy did not improve from 0.84574
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8583 - loss: 0.3720 - val_accuracy: 0.8211 - val_loss: 0.4740 - learning_rate: 5.0000e-05
# Epoch 49/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8425 - loss: 0.4146
# Epoch 49: val_accuracy did not improve from 0.84574
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.8426 - loss: 0.4146 - val_accuracy: 0.8423 - val_loss: 0.4171 - learning_rate: 5.0000e-05
# Epoch 50/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8628 - loss: 0.3555
# Epoch 50: val_accuracy did not improve from 0.84574
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 223s 126ms/step - accuracy: 0.8628 - loss: 0.3555 - val_accuracy: 0.8398 - val_loss: 0.4138 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 46.
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step
#
# Fold 3/5
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4934 - loss: 1.2013
# Epoch 1: val_accuracy improved from -inf to 0.65751, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 225s 127ms/step - accuracy: 0.4934 - loss: 1.2012 - val_accuracy: 0.6575 - val_loss: 0.8692 - learning_rate: 1.0000e-04
# Epoch 2/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6225 - loss: 0.9032
# Epoch 2: val_accuracy did not improve from 0.65751
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 222s 126ms/step - accuracy: 0.6225 - loss: 0.9031 - val_accuracy: 0.6402 - val_loss: 0.8504 - learning_rate: 1.0000e-04
# Epoch 3/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6388 - loss: 0.8389
# Epoch 3: val_accuracy did not improve from 0.65751
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 220s 125ms/step - accuracy: 0.6388 - loss: 0.8389 - val_accuracy: 0.6068 - val_loss: 0.8455 - learning_rate: 1.0000e-04
# Epoch 4/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6691 - loss: 0.7934
# Epoch 4: val_accuracy improved from 0.65751 to 0.73280, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 220s 125ms/step - accuracy: 0.6691 - loss: 0.7934 - val_accuracy: 0.7328 - val_loss: 0.7291 - learning_rate: 1.0000e-04
# Epoch 5/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.
- learning_rate: 1.0000e-04
# Epoch 21/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8024 - loss: 0.5101
# Epoch 21: val_accuracy did not improve from 0.80413
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 221s 125ms/step - accuracy: 0.8024 - loss: 0.5101 - val_accuracy: 0.7937 - val_loss: 0.5343 - learning_rate: 1.0000e-04
# Epoch 22/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8117 - loss: 0.4884
# Epoch 22: val_accuracy improved from 0.80413 to 0.80640, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 218s 123ms/step - accuracy: 0.8117 - loss: 0.4884 - val_accuracy: 0.8064 - val_loss: 0.4930 - learning_rate: 1.0000e-04
# Epoch 23/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8140 - loss: 0.4803
# Epoch 23: val_accuracy did not improve from 0.80640
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.8140 - loss: 0.4803 - val_accuracy: 0.7993 - val_loss: 0.5314 - learning_rate: 1.0000e-04
# Epoch 24/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8037 - loss: 0.4977
# Epoch 24: val_accuracy did not improve from 0.80640
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.8037 - loss: 0.4977 - val_accuracy: 0.7982 - val_loss: 0.5057 - learning_rate: 1.0000e-04
# Epoch 25/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8068 - loss: 0.4891
# Epoch 25: val_accuracy did not improve from 0.80640
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 218s 123ms/step - accuracy: 0.8068 - loss: 0.4891 - val_accuracy: 0.8055 - val_loss: 0.4932 - learning_rate: 1.0000e-04
# Epoch 26/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8115 - loss: 0.4768
# Epoch 26: val_accuracy improved from 0.80640 to 0.80696, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 218s 124ms/step - accuracy: 0.8115 - loss: 0.4768 - val_accuracy: 0.8070 - val_loss: 0.4701 - learning_rate: 1.0000e-04
# Epoch 27/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8128 - loss: 0.4747
# Epoch 27: val_accuracy did not improve from 0.80696
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 217s 123ms/step - accuracy: 0.8128 - loss: 0.4747 - val_accuracy: 0.7608 - val_loss: 0.6040 - learning_rate: 1.0000e-04
# Epoch 28/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.7908 - loss: 0.5123
# Epoch 28: val_accuracy improved from 0.80696 to 0.81008, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.7908 - loss: 0.5123 - val_accuracy: 0.8101 - val_loss: 0.4785 - learning_rate: 1.0000e-04
# Epoch 29/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8138 - loss: 0.4721
# Epoch 29: val_accuracy improved from 0.81008 to 0.81800, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 218s 123ms/step - accuracy: 0.8138 - loss: 0.4721 - val_accuracy: 0.8180 - val_loss: 0.4671 - learning_rate: 1.0000e-04
# Epoch 30/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8376 - loss: 0.4256
# Epoch 30: val_accuracy improved from 0.81800 to 0.81970, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 218s 124ms/step - accuracy: 0.8376 - loss: 0.4256 - val_accuracy: 0.8197 - val_loss: 0.4643 - learning_rate: 1.0000e-04
# Epoch 31/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8306 - loss: 0.4370
# Epoch 31: val_accuracy improved from 0.81970 to 0.82989, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.8306 - loss: 0.4370 - val_accuracy: 0.8299 - val_loss: 0.4435 - learning_rate: 1.0000e-04
# Epoch 32/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8246 - loss: 0.4458
# Epoch 32: val_accuracy did not improve from 0.82989
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 218s 124ms/step - accuracy: 0.8246 - loss: 0.4459 - val_accuracy: 0.8217 - val_loss: 0.4559 - learning_rate: 1.0000e-04
# Epoch 33/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8309 - loss: 0.4312
# Epoch 33: val_accuracy improved from 0.82989 to 0.83697, saving model to fold_results/fold_3/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.8309 - loss: 0.4313 - val_accuracy: 0.8370 - val_loss: 0.4577 - learning_rate: 1.0000e-04
# Epoch 34/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8278 - loss: 0.4637
# Epoch 34: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 220s 125ms/step - accuracy: 0.8278 - loss: 0.4637 - val_accuracy: 0.8282 - val_loss: 0.4476 - learning_rate: 1.0000e-04
# Epoch 35/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8388 - loss: 0.4289
# Epoch 35: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 218s 124ms/step - accuracy: 0.8388 - loss: 0.4289 - val_accuracy: 0.8254 - val_loss: 0.4487 - learning_rate: 1.0000e-04
# Epoch 36/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8419 - loss: 0.4182
# Epoch 36: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.8419 - loss: 0.4182 - val_accuracy: 0.8361 - val_loss: 0.4369 - learning_rate: 1.0000e-04
# Epoch 37/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8455 - loss: 0.4167
# Epoch 37: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.8455 - loss: 0.4167 - val_accuracy: 0.8361 - val_loss: 0.4326 - learning_rate: 1.0000e-04
# Epoch 38/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8441 - loss: 0.4047
# Epoch 38: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 220s 124ms/step - accuracy: 0.8441 - loss: 0.4047 - val_accuracy: 0.8324 - val_loss: 0.4340 - learning_rate: 1.0000e-04
# Epoch 39/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8496 - loss: 0.4048
# Epoch 39: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 220s 124ms/step - accuracy: 0.8496 - loss: 0.4048 - val_accuracy: 0.8265 - val_loss: 0.4448 - learning_rate: 1.0000e-04
# Epoch 40/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8230 - loss: 0.4636
# Epoch 40: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 220s 124ms/step - accuracy: 0.8230 - loss: 0.4636 - val_accuracy: 0.8339 - val_loss: 0.4456 - learning_rate: 1.0000e-04
# Epoch 41/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8386 - loss: 0.4121
# Epoch 41: val_accuracy did not improve from 0.83697
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 218s 124ms/step - accuracy: 0.8386 - loss: 0.4121 - val_accuracy: 0.8339 - val_loss: 0.4509 - learning_rate: 1.0000e-04
# Epoch 42/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8526 - loss: 0.3955
# Epoch 42: val_accuracy did not improve from 0.83697
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# ...
# Epoch 3/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7239 - loss: 0.6898
# Epoch 3: val_accuracy did not improve from 0.73422
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 217s 123ms/step - accuracy: 0.7239 - loss: 0.6898 - val_accuracy: 0.7011 - val_loss: 0.8383 - learning_rate: 1.0000e-04
# Epoch 4/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.7357 - loss: 0.6904
# Epoch 4: val_accuracy improved from 0.73422 to 0.75517, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.7357 - loss: 0.6904 - val_accuracy: 0.7552 - val_loss: 0.6189 - learning_rate: 1.0000e-04
# Epoch 5/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.7280 - loss: 0.7086
# Epoch 5: val_accuracy improved from 0.75517 to 0.76620, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 219s 124ms/step - accuracy: 0.7280 - loss: 0.7086 - val_accuracy: 0.7662 - val_loss: 0.6205 - learning_rate: 1.0000e-04
# Epoch 6/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.7540 - loss: 0.6190
# Epoch 6: val_accuracy did not improve from 0.76620
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 224s 127ms/step - accuracy: 0.7540 - loss: 0.6190 - val_accuracy: 0.7642 - val_loss: 0.6353 - learning_rate: 1.0000e-04
# Epoch 7/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.7571 - loss: 0.6125
# Epoch 7: val_accuracy did not improve from 0.76620
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 220s 125ms/step - accuracy: 0.7571 - loss: 0.6125 - val_accuracy: 0.6352 - val_loss: 1.1808 - learning_rate: 1.0000e-04
# Epoch 8/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.
- learning_rate: 1.0000e-04
# Epoch 23/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8233 - loss: 0.4394
# Epoch 23: val_accuracy did not improve from 0.83159
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 206s 117ms/step - accuracy: 0.8233 - loss: 0.4394 - val_accuracy: 0.8237 - val_loss: 0.4308 - learning_rate: 1.0000e-04
# Epoch 24/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8242 - loss: 0.4711
# Epoch 24: val_accuracy improved from 0.83159 to 0.83498, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 205s 116ms/step - accuracy: 0.8242 - loss: 0.4711 - val_accuracy: 0.8350 - val_loss: 0.4290 - learning_rate: 1.0000e-04
# Epoch 25/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8291 - loss: 0.4336
# Epoch 25: val_accuracy improved from 0.83498 to 0.83555, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 206s 117ms/step - accuracy: 0.8291 - loss: 0.4336 - val_accuracy: 0.8356 - val_loss: 0.4237 - learning_rate: 1.0000e-04
# Epoch 26/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8366 - loss: 0.4215
# Epoch 26: val_accuracy did not improve from 0.83555
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 208s 118ms/step - accuracy: 0.8366 - loss: 0.4215 - val_accuracy: 0.8271 - val_loss: 0.4373 - learning_rate: 1.0000e-04
# Epoch 27/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8347 - loss: 0.4339
# Epoch 27: val_accuracy did not improve from 0.83555
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 208s 117ms/step - accuracy: 0.8347 - loss: 0.4339 - val_accuracy: 0.8268 - val_loss: 0.4465 - learning_rate: 1.0000e-04
# Epoch 28/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8301 - loss: 0.4353
# Epoch 28: val_accuracy did not improve from 0.83555
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 208s 117ms/step - accuracy: 0.8301 - loss: 0.4353 - val_accuracy: 0.8296 - val_loss: 0.4466 - learning_rate: 1.0000e-04
# Epoch 29/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8363 - loss: 0.4244
# Epoch 29: val_accuracy did not improve from 0.83555
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 208s 118ms/step - accuracy: 0.8363 - loss: 0.4244 - val_accuracy: 0.8322 - val_loss: 0.4323 - learning_rate: 1.0000e-04
# Epoch 30/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8398 - loss: 0.4234
# Epoch 30: val_accuracy improved from 0.83555 to 0.84036, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 208s 118ms/step - accuracy: 0.8398 - loss: 0.4234 - val_accuracy: 0.8404 - val_loss: 0.4148 - learning_rate: 1.0000e-04
# Epoch 31/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8368 - loss: 0.4274
# Epoch 31: val_accuracy improved from 0.84036 to 0.84319, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 207s 117ms/step - accuracy: 0.8368 - loss: 0.4274 - val_accuracy: 0.8432 - val_loss: 0.4155 - learning_rate: 1.0000e-04
# Epoch 32/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8405 - loss: 0.4214
# Epoch 32: val_accuracy did not improve from 0.84319
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 209s 118ms/step - accuracy: 0.8405 - loss: 0.4214 - val_accuracy: 0.8350 - val_loss: 0.4629 - learning_rate: 1.0000e-04
# Epoch 33/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7414 - loss: 0.6524
# Epoch 33: val_accuracy did not improve from 0.84319
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 208s 118ms/step - accuracy: 0.7414 - loss: 0.6524 - val_accuracy: 0.8279 - val_loss: 0.4443 - learning_rate: 1.0000e-04
# Epoch 34/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7467 - loss: 0.5880
# Epoch 34: val_accuracy did not improve from 0.84319
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 209s 118ms/step - accuracy: 0.7467 - loss: 0.5880 - val_accuracy: 0.7294 - val_loss: 0.5562 - learning_rate: 1.0000e-04
# Epoch 35/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7805 - loss: 0.5235
# Epoch 35: val_accuracy did not improve from 0.84319
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.7805 - loss: 0.5235 - val_accuracy: 0.8327 - val_loss: 0.4270 - learning_rate: 1.0000e-04
# Epoch 36/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8370 - loss: 0.4278
# Epoch 36: val_accuracy improved from 0.84319 to 0.84461, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 208s 118ms/step - accuracy: 0.8370 - loss: 0.4278 - val_accuracy: 0.8446 - val_loss: 0.4124 - learning_rate: 5.0000e-05
# Epoch 37/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8460 - loss: 0.4148
# Epoch 37: val_accuracy improved from 0.84461 to 0.84687, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 209s 118ms/step - accuracy: 0.8460 - loss: 0.4148 - val_accuracy: 0.8469 - val_loss: 0.4058 - learning_rate: 5.0000e-05
# Epoch 38/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8515 - loss: 0.3954
# Epoch 38: val_accuracy improved from 0.84687 to 0.84999, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8515 - loss: 0.3954 - val_accuracy: 0.8500 - val_loss: 0.3995 - learning_rate: 5.0000e-05
# Epoch 39/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8513 - loss: 0.3889
# Epoch 39: val_accuracy did not improve from 0.84999
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 211s 119ms/step - accuracy: 0.8513 - loss: 0.3889 - val_accuracy: 0.8472 - val_loss: 0.3962 - learning_rate: 5.0000e-05
# Epoch 40/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8543 - loss: 0.3910
# Epoch 40: val_accuracy improved from 0.84999 to 0.85423, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8543 - loss: 0.3910 - val_accuracy: 0.8542 - val_loss: 0.3906 - learning_rate: 5.0000e-05
# Epoch 41/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8484 - loss: 0.3897
# Epoch 41: val_accuracy did not improve from 0.85423
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8484 - loss: 0.3897 - val_accuracy: 0.8480 - val_loss: 0.3955 - learning_rate: 5.0000e-05
# Epoch 42/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8542 - loss: 0.3739
# Epoch 42: val_accuracy did not improve from 0.85423
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8542 - loss: 0.3739 - val_accuracy: 0.8539 - val_loss: 0.3997 - learning_rate: 5.0000e-05
# Epoch 43/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8575 - loss: 0.3763
# Epoch 43: val_accuracy improved from 0.85423 to 0.85565, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8575 - loss: 0.3763 - val_accuracy: 0.8556 - val_loss: 0.3894 - learning_rate: 5.0000e-05
# Epoch 44/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8595 - loss: 0.3682
# Epoch 44: val_accuracy did not improve from 0.85565
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8595 - loss: 0.3682 - val_accuracy: 0.8500 - val_loss: 0.3961 - learning_rate: 5.0000e-05
# Epoch 45/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8594 - loss: 0.3750
# Epoch 45: val_accuracy did not improve from 0.85565
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 211s 119ms/step - accuracy: 0.8594 - loss: 0.3750 - val_accuracy: 0.8497 - val_loss: 0.3893 - learning_rate: 5.0000e-05
# Epoch 46/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8628 - loss: 0.3573
# Epoch 46: val_accuracy did not improve from 0.85565
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8628 - loss: 0.3573 - val_accuracy: 0.8500 - val_loss: 0.3941 - learning_rate: 5.0000e-05
# Epoch 47/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8642 - loss: 0.3579
# Epoch 47: val_accuracy did not improve from 0.85565
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8642 - loss: 0.3579 - val_accuracy: 0.8466 - val_loss: 0.3943 - learning_rate: 5.0000e-05
# Epoch 48/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8667 - loss: 0.3491
# Epoch 48: val_accuracy improved from 0.85565 to 0.85735, saving model to fold_results/fold_final/best_lstm_model_5class.keras
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 211s 119ms/step - accuracy: 0.8667 - loss: 0.3491 - val_accuracy: 0.8573 - val_loss: 0.3837 - learning_rate: 5.0000e-05
# Epoch 49/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8645 - loss: 0.3505
# Epoch 49: val_accuracy did not improve from 0.85735
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8645 - loss: 0.3505 - val_accuracy: 0.8412 - val_loss: 0.4067 - learning_rate: 5.0000e-05
# Epoch 50/50
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8621 - loss: 0.3605
# Epoch 50: val_accuracy did not improve from 0.85735
# 1767/1767 ━━━━━━━━━━━━━━━━━━━━ 210s 119ms/step - accuracy: 0.8621 - loss: 0.3605 - val_accuracy: 0.8503 - val_loss: 0.3901 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 48.
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def display_fold_results(fold_num, metrics, cm, class_names, history):
    """
    Fungsi untuk menampilkan hasil evaluasi setiap fold
    """
    print(f"\n{'='*50}")
    print(f"HASIL EVALUASI FOLD {fold_num}")
    print(f"{'='*50}")
    
    # Tampilkan metrics utama
    print("\nMetrics Utama:")
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print(f"Precision: {metrics['precision']:.4f}")
    print(f"Recall: {metrics['recall']:.4f}")
    print(f"F1-Score: {metrics['f1']:.4f}")
    
    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title(f'Confusion Matrix - Fold {fold_num}')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Plot training history
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    # Plot accuracy
    ax1.plot(history['accuracy'])
    ax1.plot(history['val_accuracy'])
    ax1.set_title(f'Model Accuracy - Fold {fold_num}')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['Train', 'Validation'])
    
    # Plot loss
    ax2.plot(history['loss'])
    ax2.plot(history['val_loss'])
    ax2.set_title(f'Model Loss - Fold {fold_num}')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend(['Train', 'Validation'])
    
    plt.tight_layout()
    plt.show()
    
    # Tampilkan metrics per kelas
    #print("\nMetrics per Kelas:")
    #for metrics in per_class_metrics:
        #print(f"\nKelas: {metrics['Class']}")
        #print(f"True Positives (TP): {metrics['True Positives']}")
        #print(f"True Negatives (TN): {metrics['True Negatives']}")
        #print(f"False Positives (FP): {metrics['False Positives']}")
        #print(f"False Negatives (FN): {metrics['False Negatives']}")
        #print(f"Precision: {metrics['Precision']:.4f}")
        #print(f"Recall: {metrics['Recall']:.4f}")
        #print(f"F1-Score: {metrics['F1-Score']:.4f}")
        #print(f"Specificity: {metrics['Specificity']:.4f}")

# Dalam loop K-Fold, tambahkan:
for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train)):
    fold_num = fold + 1
    print(f'\nMulai pelatihan Fold {fold_num}/{n_folds}')
    
    # ... kode training model ...
    
    # Setelah evaluasi, tampilkan hasil
    fold_metrics = evaluate_model(model, X_val_fold, y_val_fold, le.classes_, fold_num, fold_dir)
    display_fold_results(fold_num, 
                        fold_metrics,
                        fold_metrics['confusion_matrix'],
                        le.classes_,
                        history.history)
    
    fold_results.append(fold_metrics)
    fold_histories.append(history.history)

# Setelah semua fold selesai, tampilkan ringkasan
print("\n" + "="*50)
print("RINGKASAN HASIL K-FOLD CROSS VALIDATION")
print("="*50)

# Tampilkan tabel hasil
print("\nHasil per Fold:")
print(kfold_results_df.to_string(index=False))

# Plot perbandingan metrics antar fold
plt.figure(figsize=(12, 6))
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
for metric in metrics:
    plt.plot(range(1, n_folds + 1), 
             kfold_results_df[metric][:n_folds], 
             marker='o', 
             label=metric)
plt.title('Perbandingan Metrics Antar Fold')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()

# Tampilkan rata-rata dan standar deviasi
print("\nRata-rata dan Standar Deviasi Metrics:")
metrics_mean = kfold_results_df.iloc[:-1][metrics].mean()
metrics_std = kfold_results_df.iloc[:-1][metrics].std()

for metric in metrics:
    print(f"{metric}:")
    print(f"  Mean: {metrics_mean[metric]:.4f}")
    print(f"  Std:  {metrics_std[metric]:.4f}")

# Box plot untuk visualisasi distribusi metrics
plt.figure(figsize=(10, 6))
kfold_results_df.iloc[:-1][metrics].boxplot()
plt.title('Distribusi Metrics Across Folds')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# Untuk model final
print("\n" + "="*50)
print("HASIL MODEL FINAL")
print("="*50)

final_results = evaluate_model(final_model, X_test, y_test_cat, le.classes_, 'Final', final_dir)
display_fold_results('Final', 
                    final_results,
                    final_results['confusion_matrix'],
                    le.classes_,
                    final_history.history)
# Out:
# Mulai pelatihan Fold 1/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 1
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.8403
# Precision: 0.8408
# Recall: 0.8403
# F1-Score: 0.8403
# Mulai pelatihan Fold 2/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 2
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.8403
# Precision: 0.8408
# Recall: 0.8403
# F1-Score: 0.8403
# Mulai pelatihan Fold 3/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 3
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.8403
# Precision: 0.8408
# Recall: 0.8403
# F1-Score: 0.8403
# Mulai pelatihan Fold 4/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 4
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.8403
# Precision: 0.8408
# Recall: 0.8403
# F1-Score: 0.8403
# Mulai pelatihan Fold 5/5
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step
#
# ==================================================
# HASIL EVALUASI FOLD 5
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.8403
# Precision: 0.8408
# Recall: 0.8403
# F1-Score: 0.8403
# ==================================================
# RINGKASAN HASIL K-FOLD CROSS VALIDATION
# ==================================================
#
# Hasil per Fold:
#    Fold  Accuracy  Precision   Recall  F1-Score
#       1  0.840362   0.835306 0.840362  0.836045
#       2  0.843193   0.840532 0.843193  0.841362
#       3  0.839513   0.835442 0.839513  0.833617
#       4  0.839796   0.840866 0.839796  0.837610
#       5  0.840317   0.840825 0.840317  0.840286
# Average  0.840636   0.838594 0.840636  0.837784
# Rata-rata dan Standar Deviasi Metrics:
# Accuracy:
#   Mean: 0.8406
#   Std:  0.0015
# Precision:
#   Mean: 0.8386
#   Std:  0.0029
# Recall:
#   Mean: 0.8406
#   Std:  0.0015
# F1-Score:
#   Mean: 0.8378
#   Std:  0.0031
# ==================================================
# HASIL MODEL FINAL
# ==================================================
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step
#
# ==================================================
# HASIL EVALUASI FOLD Final
# ==================================================
#
# Metrics Utama:
# Accuracy: 0.8368
# Precision: 0.8403
# Recall: 0.8368
# F1-Score: 0.8368
